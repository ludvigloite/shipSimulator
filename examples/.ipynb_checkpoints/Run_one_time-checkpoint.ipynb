# %%
import route_following_simulation as file
import sys
sys.path.append('/Users/ludvigloite/projects/skole/prosjektoppgave/ship_simulator/')

import matplotlib.pyplot as plt
import numpy as np

from models import ShipModel, ShipConfiguration, EnvironmentConfiguration, \
    MachinerySystemConfiguration, SimulationConfiguration, StaticObstacle, \
    MachineryMode, MachineryModeParams, MachineryModes, ThrottleControllerGains, \
    EngineThrottleFromSpeedSetPoint, HeadingByRouteController, HeadingControllerGains, \
    SpecificFuelConsumptionWartila6L26, SpecificFuelConsumptionBaudouin6M26Dot3, LosParameters, \
    SeachartSimulationConfiguration

import pandas as pd
import shapely.geometry as geo
from random import random
from tqdm import tqdm

failure_modes= ['FM1: Full Blackout', 'FM2: 80% Power Loss', 'FM3: 50% Power Loss', 'FM4: Rudder Freeze']
probabilities = {'FM1: Full Blackout':0.0001, 'FM2: 80% Power Loss':0.0002, 'FM3: 50% Power Loss':0.0003, 'FM4: Rudder Freeze':0.001}
reductionFactor = 500

#TODO: Mistenker at throttle control ikke funker. Vet ikke helt med rudder heller. Problemer med integratoren!
#TODO: Motor shaft speed og rudder har ufysiske raske endringer

simulation_locations = ["hestholmen_east", "hestholmen_west", "tautra_north", "tautra_south", "tautra_north_tight", "tautra_south_tight"]
simulation_location = simulation_locations[4]
simulation_locations_used = simulation_locations[4:6]

nu_of_simulations = 100

draft_of_ship = 6 #Typical draft around 6m: https://horizonship.com/ship/80m-dp2-platform-supply-vessel-1-of-3-sister-ships-2020-dwt-3500/
safety_margin = 50

show_seacharts = False
show_plots = False
save_results_to_csv = False

save_risky_result_svg = False
risky_result_svg_name = ''

simulation_data = {}

simulation_data[simulation_location] = {}
simulation_data[simulation_location]["consequence"] = []

# %%
route_txt = "route_seacharts.txt"
init_north_pos = 6955000
init_east_pos = 33100
size_map_east = 18000
size_map_north = 10124
center_map_east = 36580
center_map_north = 6960000
init_yaw_angle = 90 * np.pi / 180

new_data= False
route_txt = 'route_'+simulation_location+'.txt'


if simulation_location.split('_')[0] == "hestholmen":
    init_north_pos = 6993973
    init_east_pos = 75678
    size_map_east = 18000
    size_map_north = 10124
    center_map_east = 74826
    center_map_north = 6989614
    init_yaw_angle = 180 * np.pi / 180
elif simulation_location.split('_')[0] == "tautra":
    init_north_pos = 6974308
    init_east_pos = 81150
    size_map_east = 18000
    size_map_north = 10124
    center_map_east = 85814
    center_map_north = 6974797
    init_yaw_angle = 90 * np.pi / 180



main_engine_capacity = 2160e3
diesel_gen_capacity = 510e3
hybrid_shaft_gen_as_generator = 'GEN'
hybrid_shaft_gen_as_motor = 'MOTOR'
hybrid_shaft_gen_as_offline = 'OFF'

time_step = 0.5

env_config = EnvironmentConfiguration(
    current_velocity_component_from_north=-2,#-2,
    current_velocity_component_from_east=2,#-2,
    wind_speed=15,#15,
    wind_direction=0
)

seacharts_setup = SeachartSimulationConfiguration(
    size_of_map_east = size_map_east,
    size_of_map_north = size_map_north,
    center_of_map_east = center_map_east,
    center_of_map_north = center_map_north,
    database_file_names = ['More_og_Romsdal.gdb'],
    new_data = new_data,
    border = True,
    route_txt = route_txt,
    waypoint_color = 'green',
    draft_of_ship = draft_of_ship, #Typical draft around 6m: https://horizonship.com/ship/80m-dp2-platform-supply-vessel-1-of-3-sister-ships-2020-dwt-3500/
    safety_margin = safety_margin,
    wind_arrow_drawing_coefficient = 20,
    current_arrow_drawing_coefficient = 1000,
    current_wind_arrow_offset = 500,
    wind_arrow_color = 'black',
    current_arrow_color = 'yellow',
    able_to_crash = False
)

# %%
ship_config = ShipConfiguration(
    coefficient_of_deadweight_to_displacement=0.7,
    bunkers=200000,
    ballast=200000,
    length_of_ship=80,
    width_of_ship=16,
    added_mass_coefficient_in_surge=0.4,
    added_mass_coefficient_in_sway=0.4,
    added_mass_coefficient_in_yaw=0.4,
    dead_weight_tonnage=3850000,
    mass_over_linear_friction_coefficient_in_surge=130,
    mass_over_linear_friction_coefficient_in_sway=18,
    mass_over_linear_friction_coefficient_in_yaw=90,
    nonlinear_friction_coefficient__in_surge=2400,
    nonlinear_friction_coefficient__in_sway=4000,
    nonlinear_friction_coefficient__in_yaw=400
)
mec_mode_params = MachineryModeParams(
    main_engine_capacity=main_engine_capacity,
    electrical_capacity=diesel_gen_capacity,
    shaft_generator_state=hybrid_shaft_gen_as_offline
)
mec_mode = MachineryMode(params=mec_mode_params)
mso_modes = MachineryModes(
    [mec_mode]
)
fuel_spec_me = SpecificFuelConsumptionWartila6L26()
fuel_spec_dg = SpecificFuelConsumptionBaudouin6M26Dot3()
machinery_config = MachinerySystemConfiguration(
    machinery_modes=mso_modes,
    machinery_operating_mode=0,
    linear_friction_main_engine=68,
    linear_friction_hybrid_shaft_generator=57,
    gear_ratio_between_main_engine_and_propeller=0.6,
    gear_ratio_between_hybrid_shaft_generator_and_propeller=0.6,
    propeller_inertia=6000,
    propeller_diameter=3.1,
    propeller_speed_to_torque_coefficient=7.5,
    propeller_speed_to_thrust_force_coefficient=1.7,
    hotel_load=200000,
    rated_speed_main_engine_rpm=1000,
    rudder_angle_to_sway_force_coefficient=50e3,
    rudder_angle_to_yaw_force_coefficient=500e3,
    max_rudder_angle_degrees=30,
    specific_fuel_consumption_coefficients_me=fuel_spec_me.fuel_consumption_coefficients(),
    specific_fuel_consumption_coefficients_dg=fuel_spec_dg.fuel_consumption_coefficients()
)
simulation_setup = SimulationConfiguration(
    initial_north_position_m= init_north_pos, #6955000,#6958000,
    initial_east_position_m= init_east_pos, #33100,#30000,
    initial_yaw_angle_rad=init_yaw_angle, #90 * np.pi / 180, #90 * np.pi / 180,
    initial_forward_speed_m_per_s=7,
    initial_sideways_speed_m_per_s=0,
    initial_yaw_rate_rad_per_s=0,
    integration_step=time_step,
    simulation_time=1100,#1500,#600,
)

# %%
ship_model = ShipModel(ship_config=ship_config,
                    machinery_config=machinery_config,
                    environment_config=env_config,
                    seachart_config=seacharts_setup,
                    simulation_config=simulation_setup,
                    initial_propeller_shaft_speed_rad_per_s=400 * np.pi / 30)

desired_forward_speed_meters_per_second = 8.5
time_since_last_ship_drawing = 30

# Set up control systems
throttle_controller_gains = ThrottleControllerGains(
    kp_ship_speed=7, ki_ship_speed=0.13, kp_shaft_speed=0.05, ki_shaft_speed=0.005
)
throttle_controller = EngineThrottleFromSpeedSetPoint(
    gains=throttle_controller_gains,
    max_shaft_speed=ship_model.ship_machinery_model.shaft_speed_max,
    time_step=time_step,
    initial_shaft_speed_integral_error=114
)

heading_controller_gains = HeadingControllerGains(kp=4, kd=90, ki=0.01)
los_guidance_parameters = LosParameters(
    radius_of_acceptance=200,
    lookahead_distance=500,
    integral_gain=0.002,
    integrator_windup_limit=4000
)
auto_pilot = HeadingByRouteController(
    route_name=route_txt,
    heading_controller_gains=heading_controller_gains,
    los_parameters=los_guidance_parameters,
    time_step=time_step,
    max_rudder_angle=machinery_config.max_rudder_angle_degrees * np.pi/180
)

ship_color = 'orange'

integrator_term = []
times = []
failures = []

colors = {'FM1: Full Blackout':'red', 'FM2: 80% Power Loss':'green', 'FM3: 50% Power Loss':'yellow', 'FM4: Rudder Freeze':'black'}

pbar = tqdm(total=1100)

while ship_model.int.time < ship_model.int.sim_time and auto_pilot.next_wpt != auto_pilot.prev_wpt:
    pbar.update(0.5)

    # Measure position and speed
    north_position = ship_model.north
    east_position = ship_model.east
    heading = ship_model.yaw_angle
    speed = ship_model.forward_speed

    

    # Find appropriate rudder angle and engine throttle
    rudder_angle = auto_pilot.rudder_angle_from_route(
        north_position=north_position,
        east_position=east_position,
        heading=heading
    )

    throttle = throttle_controller.throttle(
        speed_set_point=desired_forward_speed_meters_per_second,
        measured_speed=speed,
        measured_shaft_speed=speed
    )
    
    if ship_model.int.time == 200:
            throttle_controller, auto_pilot, failures = ship_model.simulate_failure(failure_type=failure_modes[0], nu_of_timesteps=500, failure_time_length=100, auto_pilot=auto_pilot, throttle_controller=throttle_controller, desired_forward_speed_meters_per_second=desired_forward_speed_meters_per_second, ship_color=colors[failure_modes[0]], rudder_angle=rudder_angle, throttle=throttle, failures=failures, printAllFailures=False)
    
    if ship_model.int.time == 300:
            throttle_controller, auto_pilot, failures = ship_model.simulate_failure(failure_type=failure_modes[1], nu_of_timesteps=500, failure_time_length=200, auto_pilot=auto_pilot, throttle_controller=throttle_controller, desired_forward_speed_meters_per_second=desired_forward_speed_meters_per_second, ship_color=colors[failure_modes[1]], rudder_angle=rudder_angle, throttle=throttle, failures=failures, printAllFailures=False)
            
    if ship_model.int.time == 400:
            throttle_controller, auto_pilot, failures = ship_model.simulate_failure(failure_type=failure_modes[2], nu_of_timesteps=500, failure_time_length=200, auto_pilot=auto_pilot, throttle_controller=throttle_controller, desired_forward_speed_meters_per_second=desired_forward_speed_meters_per_second, ship_color=colors[failure_modes[2]], rudder_angle=rudder_angle, throttle=throttle, failures=failures, printAllFailures=False)

            
    if ship_model.int.time == 100:
            throttle_controller, auto_pilot, failures = ship_model.simulate_failure(failure_type=failure_modes[3], nu_of_timesteps=500, failure_time_length=200, auto_pilot=auto_pilot, throttle_controller=throttle_controller, desired_forward_speed_meters_per_second=desired_forward_speed_meters_per_second, ship_color=colors[failure_modes[3]], rudder_angle=rudder_angle, throttle=throttle, failures=failures, printAllFailures=False)

    
    
    
    # Consequence Level Evaluation
    ship_color = 'white'

    position = geo.Point(east_position,north_position)
    dist_land = position.distance(ship_model.landGeometry)
    dist_shore = position.distance(ship_model.shoreGeometry)

    minimum_distance_to_hazard = min(dist_land, dist_shore)

    for i in range(len(ship_model.depths)):
        if ship_model.depths[i] <= ship_model.draft_of_ship:
            dist_seabed = position.distance(ship_model.seabedList[ship_model.depths[i]])
            if dist_seabed < minimum_distance_to_hazard:
                minimum_distance_to_hazard = dist_seabed

    if minimum_distance_to_hazard <= ship_model.safety_margin:
        ship_color = 'orange'
    if minimum_distance_to_hazard == 0 and ship_model.able_to_crash:
        ship_model.add_vessel_drawing(east_position=east_position, north_position=north_position, heading=heading, ship_color=ship_color)
        ship_model.enc.draw_circle((east_position,north_position), 50, 'red', thickness=10, fill=False)
        break

    # Update and integrate differential equations for current time step
    ship_model.store_simulation_data(throttle, rudder_angle)

    ship_model.update_differentials(engine_throttle=throttle, rudder_angle=rudder_angle)
    ship_model.integrate_differentials()

    integrator_term.append(auto_pilot.navigate.e_ct_int)
    times.append(ship_model.int.time)

    # Make a drawing of the ship from above every 20 second
    if time_since_last_ship_drawing > 30 or auto_pilot.next_wpt == auto_pilot.prev_wpt:
        ship_model.add_vessel_drawing(east_position=east_position, north_position=north_position, heading=heading, ship_color=ship_color)
        ship_model.ship_snap_shot()
        time_since_last_ship_drawing = 0
    time_since_last_ship_drawing += ship_model.int.dt
    # Progress time variable to the next time step
    ship_model.int.next_time()
    
pbar.close()

ship_model.enc.add_vessels(*ship_model.ship_positions)
ship_model.draw_wind_and_current_arrows()
ship_model.enc.save_image("failure_mode_example", extension='svg')
ship_model.enc.show_display()
# Out:
#  97%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊    | 1065.0/1100 [00:03<00:00, 311.22it/s]

# %%
ship_model.enc.add_vessels(*ship_model.ship_positions)
ship_model.draw_wind_and_current_arrows()
ship_model.enc.save_image("failure_mode_example", extension='png')
#ship_model.enc.show_display()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ship_model.enc.add_vessels(*ship_model.ship_positions)
#       2 ship_model.draw_wind_and_current_arrows()
#       3 ship_model.enc.save_image("failure_mode_example", extension='png')
#
# File ~/opt/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/seacharts/seacharts.py:100, in ENC.add_vessels(self, *args)
#      94 def add_vessels(self, *args: Tuple[int, int, int, int, str]) -> None:
#      95     """
#      96     Add colored vessel features to the displayed environment plot.
#      97     :param args: tuples with id, easting, northing, heading, color
#      98     :return: None
#      99     """
# --> 100     self._display.refresh_vessels(list(args))
#
# File ~/opt/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/seacharts/display/display.py:127, in Display.refresh_vessels(self, poses)
#     125 self.features.vessels_to_file(poses)
#     126 self.features.update_vessels()
# --> 127 self.update_plot()
#
# File ~/opt/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/seacharts/display/display.py:131, in Display.update_plot(self)
#     129 def update_plot(self):
#     130     self.figure.canvas.restore_region(self._background)
# --> 131     self.draw_animated_artists()
#
# File ~/opt/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/seacharts/display/display.py:143, in Display.draw_animated_artists(self)
#     141 def draw_animated_artists(self):
#     142     for artist in self.features.animated:
# --> 143         self.axes.draw_artist(artist)
#     144     try:
#     145         self.figure.canvas.blit()
#
# File ~/opt/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/matplotlib/axes/_base.py:3098, in _AxesBase.draw_artist(self, a)
#    3095 if self.figure._cachedRenderer is None:
#    3096     raise AttributeError("draw_artist can only be used after an "
#    3097                          "initial draw which caches the renderer")
# -> 3098 a.draw(self.figure._cachedRenderer)
#
# File ~/opt/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/opt/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/cartopy/mpl/feature_artist.py:213, in FeatureArtist.draw(self, renderer, *args, **kwargs)
#     211     c.set_clip_path(ax.patch)
#     212     c.set_figure(ax.figure)
# --> 213     c.draw(renderer)
#     215 # n.b. matplotlib.collection.Collection.draw returns None
#     216 return None
#
# File ~/opt/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/opt/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/matplotlib/collections.py:991, in _CollectionWithSizes.draw(self, renderer)
#     988 @artist.allow_rasterization
#     989 def draw(self, renderer):
#     990     self.set_sizes(self._sizes, self.figure.dpi)
# --> 991     super().draw(renderer)
#
# File ~/opt/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/opt/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/matplotlib/collections.py:364, in Collection.draw(self, renderer)
#     362 if not self.get_visible():
#     363     return
# --> 364 renderer.open_group(self.__class__.__name__, self.get_gid())
#     366 self.update_scalarmappable()
#     368 transform, transOffset, offsets, paths = self._prepare_points()
#
# File ~/opt/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/matplotlib/backends/backend_svg.py:636, in RendererSVG.open_group(self, s, gid)
#     634 else:
#     635     self._groupd[s] = self._groupd.get(s, 0) + 1
# --> 636     self.writer.start('g', id="%s_%d" % (s, self._groupd[s]))
#
# File ~/opt/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/matplotlib/backends/backend_svg.py:161, in XMLWriter.start(self, tag, attrib, **extra)
#     159 self.__data = []
#     160 self.__tags.append(tag)
# --> 161 self.__write(self.__indentation[:len(self.__tags) - 1])
#     162 self.__write("<%s" % tag)
#     163 for k, v in {**attrib, **extra}.items():
#
# ValueError: I/O operation on closed file.

# %%
#print(ship_model.consequence_dicts)
total_consequence = 0
for element in ship_model.consequence_dicts:
    for key, value in element.items():
        if key=='worst_violation' and value=='did_crash':
            total_consequence += 3
        elif key=='worst_violation' and value=='did_violate_safety_margin':
            total_consequence += 1

# %%
total_consequence

# %%
ship_model.consequence_dicts
# Out:
# [{'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 0.0,
#   'worst_violation': '',
#   'ending_time': 500.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 0.5,
#   'worst_violation': '',
#   'ending_time': 500.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 1.0,
#   'worst_violation': '',
#   'ending_time': 501.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 1.5,
#   'worst_violation': '',
#   'ending_time': 501.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 2.0,
#   'worst_violation': '',
#   'ending_time': 502.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 2.5,
#   'worst_violation': '',
#   'ending_time': 502.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 3.0,
#   'worst_violation': '',
#   'ending_time': 503.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 3.5,
#   'worst_violation': '',
#   'ending_time': 503.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 4.0,
#   'worst_violation': '',
#   'ending_time': 504.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 4.5,
#   'worst_violation': '',
#   'ending_time': 504.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 5.0,
#   'worst_violation': '',
#   'ending_time': 505.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 5.5,
#   'worst_violation': '',
#   'ending_time': 505.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 6.0,
#   'worst_violation': '',
#   'ending_time': 506.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 6.5,
#   'worst_violation': '',
#   'ending_time': 506.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 7.0,
#   'worst_violation': '',
#   'ending_time': 507.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 7.5,
#   'worst_violation': '',
#   'ending_time': 507.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 8.0,
#   'worst_violation': '',
#   'ending_time': 508.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 8.5,
#   'worst_violation': '',
#   'ending_time': 508.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 9.0,
#   'worst_violation': '',
#   'ending_time': 509.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 9.5,
#   'worst_violation': '',
#   'ending_time': 509.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 10.0,
#   'worst_violation': '',
#   'ending_time': 510.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 10.5,
#   'worst_violation': '',
#   'ending_time': 510.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 11.0,
#   'worst_violation': '',
#   'ending_time': 511.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 11.5,
#   'worst_violation': '',
#   'ending_time': 511.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 12.0,
#   'worst_violation': '',
#   'ending_time': 512.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 12.5,
#   'worst_violation': '',
#   'ending_time': 512.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 13.0,
#   'worst_violation': '',
#   'ending_time': 513.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 13.5,
#   'worst_violation': '',
#   'ending_time': 513.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 14.0,
#   'worst_violation': '',
#   'ending_time': 514.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 14.5,
#   'worst_violation': '',
#   'ending_time': 514.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 15.0,
#   'worst_violation': '',
#   'ending_time': 515.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 15.5,
#   'worst_violation': '',
#   'ending_time': 515.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 16.0,
#   'worst_violation': '',
#   'ending_time': 516.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 16.5,
#   'worst_violation': '',
#   'ending_time': 516.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 17.0,
#   'worst_violation': '',
#   'ending_time': 517.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 17.5,
#   'worst_violation': '',
#   'ending_time': 517.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 18.0,
#   'worst_violation': '',
#   'ending_time': 518.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 18.5,
#   'worst_violation': '',
#   'ending_time': 518.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 19.0,
#   'worst_violation': '',
#   'ending_time': 519.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 19.5,
#   'worst_violation': '',
#   'ending_time': 519.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 20.0,
#   'worst_violation': '',
#   'ending_time': 520.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 20.5,
#   'worst_violation': '',
#   'ending_time': 520.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 21.0,
#   'worst_violation': '',
#   'ending_time': 521.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 21.5,
#   'worst_violation': '',
#   'ending_time': 521.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 22.0,
#   'worst_violation': '',
#   'ending_time': 522.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 22.5,
#   'worst_violation': '',
#   'ending_time': 522.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 23.0,
#   'worst_violation': '',
#   'ending_time': 523.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 23.5,
#   'worst_violation': '',
#   'ending_time': 523.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 24.0,
#   'worst_violation': '',
#   'ending_time': 524.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 24.5,
#   'worst_violation': '',
#   'ending_time': 524.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 25.0,
#   'worst_violation': '',
#   'ending_time': 525.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 25.5,
#   'worst_violation': '',
#   'ending_time': 525.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 26.0,
#   'worst_violation': '',
#   'ending_time': 526.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 26.5,
#   'worst_violation': '',
#   'ending_time': 526.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 27.0,
#   'worst_violation': '',
#   'ending_time': 527.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 27.5,
#   'worst_violation': '',
#   'ending_time': 527.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 28.0,
#   'worst_violation': '',
#   'ending_time': 528.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 28.5,
#   'worst_violation': '',
#   'ending_time': 528.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 29.0,
#   'worst_violation': '',
#   'ending_time': 529.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 29.5,
#   'worst_violation': '',
#   'ending_time': 529.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 30.0,
#   'worst_violation': '',
#   'ending_time': 530.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 30.5,
#   'worst_violation': '',
#   'ending_time': 530.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 31.0,
#   'worst_violation': '',
#   'ending_time': 531.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 31.5,
#   'worst_violation': '',
#   'ending_time': 531.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 32.0,
#   'worst_violation': '',
#   'ending_time': 532.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 32.5,
#   'worst_violation': '',
#   'ending_time': 532.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 33.0,
#   'worst_violation': '',
#   'ending_time': 533.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 33.5,
#   'worst_violation': '',
#   'ending_time': 533.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 34.0,
#   'worst_violation': '',
#   'ending_time': 534.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 34.5,
#   'worst_violation': '',
#   'ending_time': 534.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 35.0,
#   'worst_violation': '',
#   'ending_time': 535.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 35.5,
#   'worst_violation': '',
#   'ending_time': 535.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 36.0,
#   'worst_violation': '',
#   'ending_time': 536.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 36.5,
#   'worst_violation': '',
#   'ending_time': 536.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 37.0,
#   'worst_violation': '',
#   'ending_time': 537.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 37.5,
#   'worst_violation': '',
#   'ending_time': 537.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 38.0,
#   'worst_violation': '',
#   'ending_time': 538.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 38.5,
#   'worst_violation': '',
#   'ending_time': 538.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 39.0,
#   'worst_violation': '',
#   'ending_time': 539.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 39.5,
#   'worst_violation': '',
#   'ending_time': 539.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 40.0,
#   'worst_violation': '',
#   'ending_time': 540.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 40.5,
#   'worst_violation': '',
#   'ending_time': 540.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 41.0,
#   'worst_violation': '',
#   'ending_time': 541.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 41.5,
#   'worst_violation': '',
#   'ending_time': 541.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 42.0,
#   'worst_violation': '',
#   'ending_time': 542.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 42.5,
#   'worst_violation': '',
#   'ending_time': 542.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 43.0,
#   'worst_violation': '',
#   'ending_time': 543.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 43.5,
#   'worst_violation': '',
#   'ending_time': 543.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 44.0,
#   'worst_violation': '',
#   'ending_time': 544.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 44.5,
#   'worst_violation': '',
#   'ending_time': 544.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 45.0,
#   'worst_violation': '',
#   'ending_time': 545.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 45.5,
#   'worst_violation': '',
#   'ending_time': 545.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 46.0,
#   'worst_violation': '',
#   'ending_time': 546.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 46.5,
#   'worst_violation': '',
#   'ending_time': 546.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 47.0,
#   'worst_violation': '',
#   'ending_time': 547.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 47.5,
#   'worst_violation': '',
#   'ending_time': 547.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 48.0,
#   'worst_violation': '',
#   'ending_time': 548.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 48.5,
#   'worst_violation': '',
#   'ending_time': 548.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 49.0,
#   'worst_violation': '',
#   'ending_time': 549.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 49.5,
#   'worst_violation': '',
#   'ending_time': 549.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 50.0,
#   'worst_violation': '',
#   'ending_time': 550.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 50.5,
#   'worst_violation': '',
#   'ending_time': 550.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 51.0,
#   'worst_violation': '',
#   'ending_time': 551.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 51.5,
#   'worst_violation': '',
#   'ending_time': 551.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 52.0,
#   'worst_violation': '',
#   'ending_time': 552.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 52.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 391.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 53.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 378.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 53.5,
#   'worst_violation': '',
#   'ending_time': 553.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 54.0,
#   'worst_violation': '',
#   'ending_time': 554.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 54.5,
#   'worst_violation': '',
#   'ending_time': 554.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 55.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 489.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 55.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 387.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 56.0,
#   'worst_violation': '',
#   'ending_time': 556.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 56.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 510.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 57.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 447.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 57.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 329.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 58.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 336.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 58.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 274.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 59.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 261.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 59.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 246.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 60.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 237.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 60.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 229.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 61.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 230.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 61.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 224.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 62.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 241.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 62.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 231.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 63.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 222.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 63.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 212.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 64.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 208.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 64.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 205.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 65.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 203.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 65.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 202.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 66.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 201.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 66.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 214.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 67.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 213.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 67.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 211.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 68.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 209.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 68.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 201.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 69.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 200.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 69.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 199.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 70.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 199.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 70.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 71.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 71.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 72.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 72.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 73.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 73.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 74.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 74.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 75.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 75.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 199.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 76.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 200.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 76.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 200.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 77.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 201.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 77.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 202.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 78.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 210.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 78.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 210.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 79.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 212.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 79.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 213.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 80.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 213.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 80.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 214.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 81.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 201.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 81.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 201.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 82.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 201.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 82.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 202.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 83.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 202.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 83.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 203.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 84.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 204.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 84.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 204.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 85.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 206.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 85.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 207.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 86.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 209.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 86.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 210.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 87.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 211.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 87.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 213.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 88.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 215.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 88.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 223.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 89.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 226.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 89.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 229.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 90.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 233.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 90.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 237.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 91.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 237.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 91.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 237.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 92.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 236.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 92.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 222.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 93.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 221.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 93.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 222.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 94.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 224.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 94.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 225.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 95.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 225.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 95.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 226.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 96.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 229.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 96.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 230.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 97.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 229.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 97.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 227.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 98.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 226.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 98.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 226.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 99.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 227.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 99.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 228.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 100.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 229.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 100.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 231.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 101.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 233.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 101.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 233.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 102.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 233.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 102.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 235.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 103.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 236.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 103.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 238.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 104.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 240.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 104.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 244.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 105.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 246.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 105.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 246.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 106.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 247.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 106.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 247.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 107.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 248.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 107.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 248.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 108.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 249.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 108.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 250.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 109.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 254.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 109.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 259.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 110.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 266.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 110.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 354.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 111.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 357.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 111.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 363.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 112.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 373.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 112.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 397.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 113.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 396.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 113.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 298.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 114.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 295.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 114.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 294.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 115.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 295.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 115.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 296.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 116.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 300.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 116.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 308.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 117.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 311.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 117.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 400.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 118.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 403.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 118.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 430.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 119.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 446.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 119.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 461.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 120.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 467.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 120.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 496.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 121.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 507.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 121.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 521.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 122.0,
#   'worst_violation': 'did_violate_safety_margin',
#   'ending_time': 622.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 122.5,
#   'worst_violation': 'did_violate_safety_margin',
#   'ending_time': 622.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 123.0,
#   'worst_violation': '',
#   'ending_time': 623.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 123.5,
#   'worst_violation': '',
#   'ending_time': 623.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 124.0,
#   'worst_violation': '',
#   'ending_time': 624.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 124.5,
#   'worst_violation': '',
#   'ending_time': 624.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 125.0,
#   'worst_violation': '',
#   'ending_time': 625.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 125.5,
#   'worst_violation': '',
#   'ending_time': 625.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 126.0,
#   'worst_violation': '',
#   'ending_time': 626.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 126.5,
#   'worst_violation': '',
#   'ending_time': 626.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 127.0,
#   'worst_violation': '',
#   'ending_time': 627.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 127.5,
#   'worst_violation': '',
#   'ending_time': 627.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 128.0,
#   'worst_violation': '',
#   'ending_time': 628.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 128.5,
#   'worst_violation': '',
#   'ending_time': 628.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 129.0,
#   'worst_violation': '',
#   'ending_time': 629.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 129.5,
#   'worst_violation': '',
#   'ending_time': 629.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 130.0,
#   'worst_violation': '',
#   'ending_time': 630.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 130.5,
#   'worst_violation': '',
#   'ending_time': 630.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 131.0,
#   'worst_violation': '',
#   'ending_time': 631.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 131.5,
#   'worst_violation': '',
#   'ending_time': 631.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 132.0,
#   'worst_violation': '',
#   'ending_time': 632.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 132.5,
#   'worst_violation': '',
#   'ending_time': 632.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 133.0,
#   'worst_violation': '',
#   'ending_time': 633.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 133.5,
#   'worst_violation': '',
#   'ending_time': 633.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 134.0,
#   'worst_violation': '',
#   'ending_time': 634.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 134.5,
#   'worst_violation': '',
#   'ending_time': 634.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 135.0,
#   'worst_violation': '',
#   'ending_time': 635.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 135.5,
#   'worst_violation': '',
#   'ending_time': 635.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 136.0,
#   'worst_violation': '',
#   'ending_time': 636.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 136.5,
#   'worst_violation': '',
#   'ending_time': 636.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 137.0,
#   'worst_violation': '',
#   'ending_time': 637.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 137.5,
#   'worst_violation': '',
#   'ending_time': 637.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 138.0,
#   'worst_violation': '',
#   'ending_time': 638.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 138.5,
#   'worst_violation': '',
#   'ending_time': 638.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 139.0,
#   'worst_violation': '',
#   'ending_time': 639.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 139.5,
#   'worst_violation': '',
#   'ending_time': 639.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 140.0,
#   'worst_violation': '',
#   'ending_time': 640.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 140.5,
#   'worst_violation': '',
#   'ending_time': 640.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 141.0,
#   'worst_violation': '',
#   'ending_time': 641.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 141.5,
#   'worst_violation': '',
#   'ending_time': 641.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 142.0,
#   'worst_violation': '',
#   'ending_time': 642.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 142.5,
#   'worst_violation': '',
#   'ending_time': 642.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 143.0,
#   'worst_violation': '',
#   'ending_time': 643.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 143.5,
#   'worst_violation': '',
#   'ending_time': 643.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 144.0,
#   'worst_violation': '',
#   'ending_time': 644.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 144.5,
#   'worst_violation': '',
#   'ending_time': 644.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 145.0,
#   'worst_violation': 'did_violate_safety_margin',
#   'ending_time': 645.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 145.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 633.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 146.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 625.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 146.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 623.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 147.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 619.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 147.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 606.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 148.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 598.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 148.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 591.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 149.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 601.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 149.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 598.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 150.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 593.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 150.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 588.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 151.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 581.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 151.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 559.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 152.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 553.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 152.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 549.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 153.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 552.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 153.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 546.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 154.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 540.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 154.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 539.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 155.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 536.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 155.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 533.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 156.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 532.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 156.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 532.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 157.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 532.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 157.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 532.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 158.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 533.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 158.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 535.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 159.0,
#   'worst_violation': 'did_violate_safety_margin',
#   'ending_time': 659.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 159.5,
#   'worst_violation': 'did_violate_safety_margin',
#   'ending_time': 659.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 160.0,
#   'worst_violation': 'did_violate_safety_margin',
#   'ending_time': 660.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 160.5,
#   'worst_violation': '',
#   'ending_time': 660.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 161.0,
#   'worst_violation': '',
#   'ending_time': 661.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 161.5,
#   'worst_violation': '',
#   'ending_time': 661.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 162.0,
#   'worst_violation': '',
#   'ending_time': 662.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 162.5,
#   'worst_violation': '',
#   'ending_time': 662.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 163.0,
#   'worst_violation': '',
#   'ending_time': 663.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 163.5,
#   'worst_violation': '',
#   'ending_time': 663.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 164.0,
#   'worst_violation': '',
#   'ending_time': 664.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 164.5,
#   'worst_violation': '',
#   'ending_time': 664.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 165.0,
#   'worst_violation': '',
#   'ending_time': 665.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 165.5,
#   'worst_violation': '',
#   'ending_time': 665.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 166.0,
#   'worst_violation': '',
#   'ending_time': 666.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 166.5,
#   'worst_violation': '',
#   'ending_time': 666.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 167.0,
#   'worst_violation': '',
#   'ending_time': 667.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 167.5,
#   'worst_violation': '',
#   'ending_time': 667.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 168.0,
#   'worst_violation': '',
#   'ending_time': 668.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 168.5,
#   'worst_violation': '',
#   'ending_time': 668.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 169.0,
#   'worst_violation': '',
#   'ending_time': 669.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 169.5,
#   'worst_violation': '',
#   'ending_time': 669.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 170.0,
#   'worst_violation': '',
#   'ending_time': 670.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 170.5,
#   'worst_violation': '',
#   'ending_time': 670.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 171.0,
#   'worst_violation': '',
#   'ending_time': 671.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 171.5,
#   'worst_violation': '',
#   'ending_time': 671.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 172.0,
#   'worst_violation': '',
#   'ending_time': 672.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 172.5,
#   'worst_violation': '',
#   'ending_time': 672.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 173.0,
#   'worst_violation': '',
#   'ending_time': 673.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 173.5,
#   'worst_violation': '',
#   'ending_time': 673.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 174.0,
#   'worst_violation': '',
#   'ending_time': 674.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 174.5,
#   'worst_violation': '',
#   'ending_time': 674.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 175.0,
#   'worst_violation': '',
#   'ending_time': 675.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 175.5,
#   'worst_violation': '',
#   'ending_time': 675.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 176.0,
#   'worst_violation': '',
#   'ending_time': 676.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 176.5,
#   'worst_violation': '',
#   'ending_time': 676.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 177.0,
#   'worst_violation': '',
#   'ending_time': 677.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 177.5,
#   'worst_violation': '',
#   'ending_time': 677.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 178.0,
#   'worst_violation': '',
#   'ending_time': 678.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 178.5,
#   'worst_violation': '',
#   'ending_time': 678.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 179.0,
#   'worst_violation': '',
#   'ending_time': 679.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 179.5,
#   'worst_violation': 'did_violate_safety_margin',
#   'ending_time': 679.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 180.0,
#   'worst_violation': 'did_violate_safety_margin',
#   'ending_time': 680.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 180.5,
#   'worst_violation': 'did_violate_safety_margin',
#   'ending_time': 680.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 181.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 554.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 181.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 530.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 182.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 529.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 182.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 528.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 183.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 528.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 183.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 528.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 184.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 528.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 184.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 530.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 185.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 533.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 185.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 535.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 186.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 539.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 186.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 546.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 187.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 544.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 187.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 546.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 188.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 551.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 188.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 574.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 189.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 581.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 189.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 586.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 190.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 590.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 190.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 594.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 191.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 584.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 191.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 591.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 192.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 601.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 192.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 615.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 193.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 616.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 193.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 621.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 194.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 635.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 194.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 650.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 195.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 661.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 195.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 678.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 196.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 692.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 196.5,
#   'worst_violation': '',
#   'ending_time': 696.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 197.0,
#   'worst_violation': '',
#   'ending_time': 697.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 197.5,
#   'worst_violation': '',
#   'ending_time': 697.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 198.0,
#   'worst_violation': '',
#   'ending_time': 698.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 198.5,
#   'worst_violation': '',
#   'ending_time': 698.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 199.0,
# ...
#   'starting_time': 431.0,
#   'worst_violation': '',
#   'ending_time': 931.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 431.5,
#   'worst_violation': '',
#   'ending_time': 931.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 432.0,
#   'worst_violation': '',
#   'ending_time': 932.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 432.5,
#   'worst_violation': '',
#   'ending_time': 932.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 433.0,
#   'worst_violation': '',
#   'ending_time': 933.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 433.5,
#   'worst_violation': '',
#   'ending_time': 933.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 434.0,
#   'worst_violation': '',
#   'ending_time': 934.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 434.5,
#   'worst_violation': '',
#   'ending_time': 934.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 435.0,
#   'worst_violation': '',
#   'ending_time': 935.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 435.5,
#   'worst_violation': '',
#   'ending_time': 935.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 436.0,
#   'worst_violation': '',
#   'ending_time': 936.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 436.5,
#   'worst_violation': '',
#   'ending_time': 936.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 437.0,
#   'worst_violation': '',
#   'ending_time': 937.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 437.5,
#   'worst_violation': '',
#   'ending_time': 937.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 438.0,
#   'worst_violation': '',
#   'ending_time': 938.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 438.5,
#   'worst_violation': '',
#   'ending_time': 938.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 439.0,
#   'worst_violation': '',
#   'ending_time': 939.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 439.5,
#   'worst_violation': '',
#   'ending_time': 939.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 440.0,
#   'worst_violation': '',
#   'ending_time': 940.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 440.5,
#   'worst_violation': '',
#   'ending_time': 940.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 441.0,
#   'worst_violation': '',
#   'ending_time': 941.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 441.5,
#   'worst_violation': '',
#   'ending_time': 941.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 442.0,
#   'worst_violation': '',
#   'ending_time': 942.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 442.5,
#   'worst_violation': '',
#   'ending_time': 942.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 443.0,
#   'worst_violation': '',
#   'ending_time': 943.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 443.5,
#   'worst_violation': '',
#   'ending_time': 943.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 444.0,
#   'worst_violation': '',
#   'ending_time': 944.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 444.5,
#   'worst_violation': '',
#   'ending_time': 944.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 445.0,
#   'worst_violation': '',
#   'ending_time': 945.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 445.5,
#   'worst_violation': '',
#   'ending_time': 945.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 446.0,
#   'worst_violation': '',
#   'ending_time': 946.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 446.5,
#   'worst_violation': '',
#   'ending_time': 946.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 447.0,
#   'worst_violation': '',
#   'ending_time': 947.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 447.5,
#   'worst_violation': '',
#   'ending_time': 947.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 448.0,
#   'worst_violation': '',
#   'ending_time': 948.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 448.5,
#   'worst_violation': '',
#   'ending_time': 948.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 449.0,
#   'worst_violation': '',
#   'ending_time': 949.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 449.5,
#   'worst_violation': '',
#   'ending_time': 949.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 450.0,
#   'worst_violation': '',
#   'ending_time': 950.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 450.5,
#   'worst_violation': '',
#   'ending_time': 950.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 451.0,
#   'worst_violation': '',
#   'ending_time': 951.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 451.5,
#   'worst_violation': '',
#   'ending_time': 951.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 452.0,
#   'worst_violation': '',
#   'ending_time': 952.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 452.5,
#   'worst_violation': '',
#   'ending_time': 952.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 453.0,
#   'worst_violation': '',
#   'ending_time': 953.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 453.5,
#   'worst_violation': '',
#   'ending_time': 953.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 454.0,
#   'worst_violation': '',
#   'ending_time': 954.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 454.5,
#   'worst_violation': '',
#   'ending_time': 954.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 455.0,
#   'worst_violation': '',
#   'ending_time': 955.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 455.5,
#   'worst_violation': '',
#   'ending_time': 955.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 456.0,
#   'worst_violation': '',
#   'ending_time': 956.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 456.5,
#   'worst_violation': '',
#   'ending_time': 956.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 457.0,
#   'worst_violation': '',
#   'ending_time': 957.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 457.5,
#   'worst_violation': '',
#   'ending_time': 957.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 458.0,
#   'worst_violation': '',
#   'ending_time': 958.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 458.5,
#   'worst_violation': '',
#   'ending_time': 958.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 459.0,
#   'worst_violation': '',
#   'ending_time': 959.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 459.5,
#   'worst_violation': '',
#   'ending_time': 959.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 460.0,
#   'worst_violation': '',
#   'ending_time': 960.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 460.5,
#   'worst_violation': '',
#   'ending_time': 960.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 461.0,
#   'worst_violation': '',
#   'ending_time': 961.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 461.5,
#   'worst_violation': '',
#   'ending_time': 961.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 462.0,
#   'worst_violation': '',
#   'ending_time': 962.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 462.5,
#   'worst_violation': '',
#   'ending_time': 962.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 463.0,
#   'worst_violation': '',
#   'ending_time': 963.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 463.5,
#   'worst_violation': '',
#   'ending_time': 963.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 464.0,
#   'worst_violation': '',
#   'ending_time': 964.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 464.5,
#   'worst_violation': '',
#   'ending_time': 964.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 465.0,
#   'worst_violation': '',
#   'ending_time': 965.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 465.5,
#   'worst_violation': '',
#   'ending_time': 965.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 466.0,
#   'worst_violation': '',
#   'ending_time': 966.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 466.5,
#   'worst_violation': '',
#   'ending_time': 966.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 467.0,
#   'worst_violation': '',
#   'ending_time': 967.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 467.5,
#   'worst_violation': '',
#   'ending_time': 967.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 468.0,
#   'worst_violation': '',
#   'ending_time': 968.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 468.5,
#   'worst_violation': '',
#   'ending_time': 968.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 469.0,
#   'worst_violation': '',
#   'ending_time': 969.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 469.5,
#   'worst_violation': '',
#   'ending_time': 969.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 470.0,
#   'worst_violation': '',
#   'ending_time': 970.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 470.5,
#   'worst_violation': '',
#   'ending_time': 970.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 471.0,
#   'worst_violation': '',
#   'ending_time': 971.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 471.5,
#   'worst_violation': '',
#   'ending_time': 971.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 472.0,
#   'worst_violation': '',
#   'ending_time': 972.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 472.5,
#   'worst_violation': '',
#   'ending_time': 972.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 473.0,
#   'worst_violation': '',
#   'ending_time': 973.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 473.5,
#   'worst_violation': '',
#   'ending_time': 973.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 474.0,
#   'worst_violation': '',
#   'ending_time': 974.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 474.5,
#   'worst_violation': '',
#   'ending_time': 974.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 475.0,
#   'worst_violation': '',
#   'ending_time': 975.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 475.5,
#   'worst_violation': '',
#   'ending_time': 975.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 476.0,
#   'worst_violation': '',
#   'ending_time': 976.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 476.5,
#   'worst_violation': '',
#   'ending_time': 976.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 477.0,
#   'worst_violation': '',
#   'ending_time': 977.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 477.5,
#   'worst_violation': '',
#   'ending_time': 977.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 478.0,
#   'worst_violation': '',
#   'ending_time': 978.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 478.5,
#   'worst_violation': '',
#   'ending_time': 978.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 479.0,
#   'worst_violation': '',
#   'ending_time': 979.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 479.5,
#   'worst_violation': '',
#   'ending_time': 979.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 480.0,
#   'worst_violation': '',
#   'ending_time': 980.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 480.5,
#   'worst_violation': '',
#   'ending_time': 980.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 481.0,
#   'worst_violation': '',
#   'ending_time': 981.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 481.5,
#   'worst_violation': '',
#   'ending_time': 981.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 482.0,
#   'worst_violation': '',
#   'ending_time': 982.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 482.5,
#   'worst_violation': '',
#   'ending_time': 982.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 483.0,
#   'worst_violation': '',
#   'ending_time': 983.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 483.5,
#   'worst_violation': '',
#   'ending_time': 983.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 484.0,
#   'worst_violation': '',
#   'ending_time': 984.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 484.5,
#   'worst_violation': '',
#   'ending_time': 984.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 485.0,
#   'worst_violation': '',
#   'ending_time': 985.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 485.5,
#   'worst_violation': '',
#   'ending_time': 985.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 486.0,
#   'worst_violation': '',
#   'ending_time': 986.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 486.5,
#   'worst_violation': '',
#   'ending_time': 986.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 487.0,
#   'worst_violation': '',
#   'ending_time': 987.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 487.5,
#   'worst_violation': '',
#   'ending_time': 987.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 488.0,
#   'worst_violation': '',
#   'ending_time': 988.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 488.5,
#   'worst_violation': '',
#   'ending_time': 988.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 489.0,
#   'worst_violation': '',
#   'ending_time': 989.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 489.5,
#   'worst_violation': '',
#   'ending_time': 989.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 490.0,
#   'worst_violation': '',
#   'ending_time': 990.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 490.5,
#   'worst_violation': '',
#   'ending_time': 990.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 491.0,
#   'worst_violation': '',
#   'ending_time': 991.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 491.5,
#   'worst_violation': '',
#   'ending_time': 991.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 492.0,
#   'worst_violation': '',
#   'ending_time': 992.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 492.5,
#   'worst_violation': '',
#   'ending_time': 992.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 493.0,
#   'worst_violation': '',
#   'ending_time': 993.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 493.5,
#   'worst_violation': '',
#   'ending_time': 993.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 494.0,
#   'worst_violation': '',
#   'ending_time': 994.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 494.5,
#   'worst_violation': '',
#   'ending_time': 994.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 495.0,
#   'worst_violation': '',
#   'ending_time': 995.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 495.5,
#   'worst_violation': '',
#   'ending_time': 995.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 496.0,
#   'worst_violation': '',
#   'ending_time': 996.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 496.5,
#   'worst_violation': '',
#   'ending_time': 996.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 497.0,
#   'worst_violation': '',
#   'ending_time': 997.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 497.5,
#   'worst_violation': '',
#   'ending_time': 997.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 498.0,
#   'worst_violation': '',
#   'ending_time': 998.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 498.5,
#   'worst_violation': '',
#   'ending_time': 998.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 499.0,
#   'worst_violation': '',
#   'ending_time': 999.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 499.5,
#   'worst_violation': '',
#   'ending_time': 999.5},
#  ...]

# %%
count_crash = 0
count_safety_margin = 0
for element in ship_model.consequence_dicts:
    #if element['failure_mode'] == 'FM1: Full Blackout':        
    if element['worst_violation']=='did_crash':
        count_crash += 1
    elif element['worst_violation']=='did_violate_safety_margin':
        count_safety_margin += 1
print("nu of crashes:", count_crash)
print("nu of safety margin: ",count_safety_margin)
print("total failure simulations: 8480")

# %%
[933,110], 0, 0, [316,14]

# %%
Tot = [1249, 124]

# %%
import pickle

# %%
with open('dict_north_only_FM4.pkl', 'wb') as f:
    pickle.dump(ship_model.consequence_dicts, f)

# %%
with open('dict_north_only_FM4.pkl', 'rb') as f:
    loaded_dict = pickle.load(f)

# %%
loaded_dict
# Out:
# [{'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 0.0,
#   'worst_violation': '',
#   'ending_time': 500.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 0.5,
#   'worst_violation': '',
#   'ending_time': 500.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 1.0,
#   'worst_violation': '',
#   'ending_time': 501.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 1.5,
#   'worst_violation': '',
#   'ending_time': 501.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 2.0,
#   'worst_violation': '',
#   'ending_time': 502.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 2.5,
#   'worst_violation': '',
#   'ending_time': 502.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 3.0,
#   'worst_violation': '',
#   'ending_time': 503.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 3.5,
#   'worst_violation': '',
#   'ending_time': 503.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 4.0,
#   'worst_violation': '',
#   'ending_time': 504.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 4.5,
#   'worst_violation': '',
#   'ending_time': 504.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 5.0,
#   'worst_violation': '',
#   'ending_time': 505.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 5.5,
#   'worst_violation': '',
#   'ending_time': 505.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 6.0,
#   'worst_violation': '',
#   'ending_time': 506.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 6.5,
#   'worst_violation': '',
#   'ending_time': 506.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 7.0,
#   'worst_violation': '',
#   'ending_time': 507.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 7.5,
#   'worst_violation': '',
#   'ending_time': 507.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 8.0,
#   'worst_violation': '',
#   'ending_time': 508.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 8.5,
#   'worst_violation': '',
#   'ending_time': 508.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 9.0,
#   'worst_violation': '',
#   'ending_time': 509.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 9.5,
#   'worst_violation': '',
#   'ending_time': 509.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 10.0,
#   'worst_violation': '',
#   'ending_time': 510.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 10.5,
#   'worst_violation': '',
#   'ending_time': 510.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 11.0,
#   'worst_violation': '',
#   'ending_time': 511.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 11.5,
#   'worst_violation': '',
#   'ending_time': 511.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 12.0,
#   'worst_violation': '',
#   'ending_time': 512.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 12.5,
#   'worst_violation': '',
#   'ending_time': 512.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 13.0,
#   'worst_violation': '',
#   'ending_time': 513.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 13.5,
#   'worst_violation': '',
#   'ending_time': 513.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 14.0,
#   'worst_violation': '',
#   'ending_time': 514.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 14.5,
#   'worst_violation': '',
#   'ending_time': 514.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 15.0,
#   'worst_violation': '',
#   'ending_time': 515.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 15.5,
#   'worst_violation': '',
#   'ending_time': 515.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 16.0,
#   'worst_violation': '',
#   'ending_time': 516.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 16.5,
#   'worst_violation': '',
#   'ending_time': 516.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 17.0,
#   'worst_violation': '',
#   'ending_time': 517.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 17.5,
#   'worst_violation': '',
#   'ending_time': 517.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 18.0,
#   'worst_violation': '',
#   'ending_time': 518.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 18.5,
#   'worst_violation': '',
#   'ending_time': 518.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 19.0,
#   'worst_violation': '',
#   'ending_time': 519.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 19.5,
#   'worst_violation': '',
#   'ending_time': 519.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 20.0,
#   'worst_violation': '',
#   'ending_time': 520.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 20.5,
#   'worst_violation': '',
#   'ending_time': 520.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 21.0,
#   'worst_violation': '',
#   'ending_time': 521.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 21.5,
#   'worst_violation': '',
#   'ending_time': 521.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 22.0,
#   'worst_violation': '',
#   'ending_time': 522.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 22.5,
#   'worst_violation': '',
#   'ending_time': 522.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 23.0,
#   'worst_violation': '',
#   'ending_time': 523.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 23.5,
#   'worst_violation': '',
#   'ending_time': 523.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 24.0,
#   'worst_violation': '',
#   'ending_time': 524.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 24.5,
#   'worst_violation': '',
#   'ending_time': 524.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 25.0,
#   'worst_violation': '',
#   'ending_time': 525.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 25.5,
#   'worst_violation': '',
#   'ending_time': 525.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 26.0,
#   'worst_violation': '',
#   'ending_time': 526.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 26.5,
#   'worst_violation': '',
#   'ending_time': 526.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 27.0,
#   'worst_violation': '',
#   'ending_time': 527.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 27.5,
#   'worst_violation': '',
#   'ending_time': 527.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 28.0,
#   'worst_violation': '',
#   'ending_time': 528.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 28.5,
#   'worst_violation': '',
#   'ending_time': 528.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 29.0,
#   'worst_violation': '',
#   'ending_time': 529.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 29.5,
#   'worst_violation': '',
#   'ending_time': 529.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 30.0,
#   'worst_violation': '',
#   'ending_time': 530.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 30.5,
#   'worst_violation': '',
#   'ending_time': 530.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 31.0,
#   'worst_violation': '',
#   'ending_time': 531.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 31.5,
#   'worst_violation': '',
#   'ending_time': 531.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 32.0,
#   'worst_violation': '',
#   'ending_time': 532.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 32.5,
#   'worst_violation': '',
#   'ending_time': 532.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 33.0,
#   'worst_violation': '',
#   'ending_time': 533.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 33.5,
#   'worst_violation': '',
#   'ending_time': 533.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 34.0,
#   'worst_violation': '',
#   'ending_time': 534.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 34.5,
#   'worst_violation': '',
#   'ending_time': 534.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 35.0,
#   'worst_violation': '',
#   'ending_time': 535.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 35.5,
#   'worst_violation': '',
#   'ending_time': 535.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 36.0,
#   'worst_violation': '',
#   'ending_time': 536.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 36.5,
#   'worst_violation': '',
#   'ending_time': 536.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 37.0,
#   'worst_violation': '',
#   'ending_time': 537.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 37.5,
#   'worst_violation': '',
#   'ending_time': 537.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 38.0,
#   'worst_violation': '',
#   'ending_time': 538.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 38.5,
#   'worst_violation': '',
#   'ending_time': 538.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 39.0,
#   'worst_violation': '',
#   'ending_time': 539.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 39.5,
#   'worst_violation': '',
#   'ending_time': 539.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 40.0,
#   'worst_violation': '',
#   'ending_time': 540.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 40.5,
#   'worst_violation': '',
#   'ending_time': 540.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 41.0,
#   'worst_violation': '',
#   'ending_time': 541.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 41.5,
#   'worst_violation': '',
#   'ending_time': 541.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 42.0,
#   'worst_violation': '',
#   'ending_time': 542.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 42.5,
#   'worst_violation': '',
#   'ending_time': 542.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 43.0,
#   'worst_violation': '',
#   'ending_time': 543.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 43.5,
#   'worst_violation': '',
#   'ending_time': 543.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 44.0,
#   'worst_violation': '',
#   'ending_time': 544.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 44.5,
#   'worst_violation': '',
#   'ending_time': 544.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 45.0,
#   'worst_violation': '',
#   'ending_time': 545.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 45.5,
#   'worst_violation': '',
#   'ending_time': 545.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 46.0,
#   'worst_violation': '',
#   'ending_time': 546.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 46.5,
#   'worst_violation': '',
#   'ending_time': 546.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 47.0,
#   'worst_violation': '',
#   'ending_time': 547.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 47.5,
#   'worst_violation': '',
#   'ending_time': 547.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 48.0,
#   'worst_violation': '',
#   'ending_time': 548.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 48.5,
#   'worst_violation': '',
#   'ending_time': 548.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 49.0,
#   'worst_violation': '',
#   'ending_time': 549.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 49.5,
#   'worst_violation': '',
#   'ending_time': 549.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 50.0,
#   'worst_violation': '',
#   'ending_time': 550.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 50.5,
#   'worst_violation': '',
#   'ending_time': 550.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 51.0,
#   'worst_violation': '',
#   'ending_time': 551.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 51.5,
#   'worst_violation': '',
#   'ending_time': 551.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 52.0,
#   'worst_violation': '',
#   'ending_time': 552.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 52.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 391.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 53.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 378.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 53.5,
#   'worst_violation': '',
#   'ending_time': 553.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 54.0,
#   'worst_violation': '',
#   'ending_time': 554.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 54.5,
#   'worst_violation': '',
#   'ending_time': 554.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 55.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 489.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 55.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 387.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 56.0,
#   'worst_violation': '',
#   'ending_time': 556.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 56.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 510.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 57.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 447.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 57.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 329.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 58.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 336.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 58.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 274.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 59.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 261.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 59.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 246.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 60.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 237.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 60.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 229.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 61.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 230.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 61.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 224.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 62.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 241.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 62.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 231.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 63.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 222.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 63.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 212.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 64.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 208.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 64.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 205.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 65.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 203.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 65.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 202.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 66.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 201.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 66.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 214.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 67.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 213.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 67.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 211.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 68.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 209.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 68.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 201.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 69.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 200.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 69.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 199.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 70.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 199.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 70.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 71.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 71.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 72.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 72.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 73.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 73.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 74.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 74.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 75.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 198.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 75.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 199.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 76.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 200.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 76.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 200.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 77.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 201.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 77.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 202.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 78.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 210.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 78.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 210.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 79.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 212.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 79.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 213.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 80.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 213.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 80.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 214.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 81.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 201.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 81.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 201.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 82.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 201.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 82.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 202.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 83.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 202.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 83.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 203.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 84.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 204.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 84.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 204.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 85.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 206.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 85.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 207.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 86.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 209.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 86.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 210.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 87.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 211.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 87.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 213.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 88.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 215.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 88.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 223.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 89.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 226.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 89.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 229.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 90.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 233.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 90.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 237.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 91.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 237.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 91.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 237.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 92.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 236.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 92.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 222.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 93.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 221.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 93.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 222.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 94.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 224.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 94.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 225.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 95.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 225.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 95.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 226.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 96.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 229.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 96.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 230.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 97.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 229.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 97.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 227.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 98.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 226.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 98.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 226.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 99.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 227.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 99.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 228.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 100.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 229.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 100.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 231.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 101.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 233.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 101.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 233.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 102.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 233.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 102.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 235.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 103.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 236.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 103.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 238.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 104.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 240.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 104.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 244.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 105.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 246.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 105.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 246.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 106.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 247.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 106.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 247.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 107.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 248.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 107.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 248.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 108.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 249.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 108.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 250.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 109.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 254.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 109.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 259.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 110.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 266.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 110.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 354.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 111.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 357.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 111.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 363.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 112.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 373.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 112.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 397.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 113.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 396.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 113.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 298.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 114.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 295.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 114.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 294.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 115.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 295.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 115.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 296.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 116.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 300.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 116.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 308.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 117.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 311.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 117.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 400.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 118.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 403.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 118.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 430.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 119.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 446.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 119.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 461.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 120.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 467.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 120.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 496.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 121.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 507.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 121.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 521.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 122.0,
#   'worst_violation': 'did_violate_safety_margin',
#   'ending_time': 622.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 122.5,
#   'worst_violation': 'did_violate_safety_margin',
#   'ending_time': 622.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 123.0,
#   'worst_violation': '',
#   'ending_time': 623.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 123.5,
#   'worst_violation': '',
#   'ending_time': 623.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 124.0,
#   'worst_violation': '',
#   'ending_time': 624.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 124.5,
#   'worst_violation': '',
#   'ending_time': 624.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 125.0,
#   'worst_violation': '',
#   'ending_time': 625.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 125.5,
#   'worst_violation': '',
#   'ending_time': 625.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 126.0,
#   'worst_violation': '',
#   'ending_time': 626.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 126.5,
#   'worst_violation': '',
#   'ending_time': 626.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 127.0,
#   'worst_violation': '',
#   'ending_time': 627.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 127.5,
#   'worst_violation': '',
#   'ending_time': 627.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 128.0,
#   'worst_violation': '',
#   'ending_time': 628.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 128.5,
#   'worst_violation': '',
#   'ending_time': 628.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 129.0,
#   'worst_violation': '',
#   'ending_time': 629.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 129.5,
#   'worst_violation': '',
#   'ending_time': 629.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 130.0,
#   'worst_violation': '',
#   'ending_time': 630.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 130.5,
#   'worst_violation': '',
#   'ending_time': 630.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 131.0,
#   'worst_violation': '',
#   'ending_time': 631.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 131.5,
#   'worst_violation': '',
#   'ending_time': 631.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 132.0,
#   'worst_violation': '',
#   'ending_time': 632.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 132.5,
#   'worst_violation': '',
#   'ending_time': 632.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 133.0,
#   'worst_violation': '',
#   'ending_time': 633.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 133.5,
#   'worst_violation': '',
#   'ending_time': 633.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 134.0,
#   'worst_violation': '',
#   'ending_time': 634.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 134.5,
#   'worst_violation': '',
#   'ending_time': 634.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 135.0,
#   'worst_violation': '',
#   'ending_time': 635.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 135.5,
#   'worst_violation': '',
#   'ending_time': 635.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 136.0,
#   'worst_violation': '',
#   'ending_time': 636.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 136.5,
#   'worst_violation': '',
#   'ending_time': 636.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 137.0,
#   'worst_violation': '',
#   'ending_time': 637.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 137.5,
#   'worst_violation': '',
#   'ending_time': 637.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 138.0,
#   'worst_violation': '',
#   'ending_time': 638.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 138.5,
#   'worst_violation': '',
#   'ending_time': 638.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 139.0,
#   'worst_violation': '',
#   'ending_time': 639.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 139.5,
#   'worst_violation': '',
#   'ending_time': 639.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 140.0,
#   'worst_violation': '',
#   'ending_time': 640.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 140.5,
#   'worst_violation': '',
#   'ending_time': 640.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 141.0,
#   'worst_violation': '',
#   'ending_time': 641.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 141.5,
#   'worst_violation': '',
#   'ending_time': 641.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 142.0,
#   'worst_violation': '',
#   'ending_time': 642.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 142.5,
#   'worst_violation': '',
#   'ending_time': 642.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 143.0,
#   'worst_violation': '',
#   'ending_time': 643.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 143.5,
#   'worst_violation': '',
#   'ending_time': 643.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 144.0,
#   'worst_violation': '',
#   'ending_time': 644.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 144.5,
#   'worst_violation': '',
#   'ending_time': 644.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 145.0,
#   'worst_violation': 'did_violate_safety_margin',
#   'ending_time': 645.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 145.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 633.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 146.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 625.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 146.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 623.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 147.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 619.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 147.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 606.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 148.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 598.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 148.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 591.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 149.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 601.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 149.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 598.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 150.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 593.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 150.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 588.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 151.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 581.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 151.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 559.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 152.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 553.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 152.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 549.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 153.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 552.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 153.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 546.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 154.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 540.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 154.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 539.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 155.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 536.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 155.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 533.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 156.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 532.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 156.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 532.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 157.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 532.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 157.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 532.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 158.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 533.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 158.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 535.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 159.0,
#   'worst_violation': 'did_violate_safety_margin',
#   'ending_time': 659.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 159.5,
#   'worst_violation': 'did_violate_safety_margin',
#   'ending_time': 659.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 160.0,
#   'worst_violation': 'did_violate_safety_margin',
#   'ending_time': 660.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 160.5,
#   'worst_violation': '',
#   'ending_time': 660.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 161.0,
#   'worst_violation': '',
#   'ending_time': 661.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 161.5,
#   'worst_violation': '',
#   'ending_time': 661.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 162.0,
#   'worst_violation': '',
#   'ending_time': 662.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 162.5,
#   'worst_violation': '',
#   'ending_time': 662.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 163.0,
#   'worst_violation': '',
#   'ending_time': 663.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 163.5,
#   'worst_violation': '',
#   'ending_time': 663.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 164.0,
#   'worst_violation': '',
#   'ending_time': 664.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 164.5,
#   'worst_violation': '',
#   'ending_time': 664.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 165.0,
#   'worst_violation': '',
#   'ending_time': 665.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 165.5,
#   'worst_violation': '',
#   'ending_time': 665.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 166.0,
#   'worst_violation': '',
#   'ending_time': 666.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 166.5,
#   'worst_violation': '',
#   'ending_time': 666.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 167.0,
#   'worst_violation': '',
#   'ending_time': 667.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 167.5,
#   'worst_violation': '',
#   'ending_time': 667.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 168.0,
#   'worst_violation': '',
#   'ending_time': 668.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 168.5,
#   'worst_violation': '',
#   'ending_time': 668.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 169.0,
#   'worst_violation': '',
#   'ending_time': 669.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 169.5,
#   'worst_violation': '',
#   'ending_time': 669.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 170.0,
#   'worst_violation': '',
#   'ending_time': 670.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 170.5,
#   'worst_violation': '',
#   'ending_time': 670.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 171.0,
#   'worst_violation': '',
#   'ending_time': 671.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 171.5,
#   'worst_violation': '',
#   'ending_time': 671.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 172.0,
#   'worst_violation': '',
#   'ending_time': 672.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 172.5,
#   'worst_violation': '',
#   'ending_time': 672.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 173.0,
#   'worst_violation': '',
#   'ending_time': 673.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 173.5,
#   'worst_violation': '',
#   'ending_time': 673.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 174.0,
#   'worst_violation': '',
#   'ending_time': 674.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 174.5,
#   'worst_violation': '',
#   'ending_time': 674.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 175.0,
#   'worst_violation': '',
#   'ending_time': 675.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 175.5,
#   'worst_violation': '',
#   'ending_time': 675.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 176.0,
#   'worst_violation': '',
#   'ending_time': 676.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 176.5,
#   'worst_violation': '',
#   'ending_time': 676.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 177.0,
#   'worst_violation': '',
#   'ending_time': 677.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 177.5,
#   'worst_violation': '',
#   'ending_time': 677.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 178.0,
#   'worst_violation': '',
#   'ending_time': 678.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 178.5,
#   'worst_violation': '',
#   'ending_time': 678.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 179.0,
#   'worst_violation': '',
#   'ending_time': 679.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 179.5,
#   'worst_violation': 'did_violate_safety_margin',
#   'ending_time': 679.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 180.0,
#   'worst_violation': 'did_violate_safety_margin',
#   'ending_time': 680.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 180.5,
#   'worst_violation': 'did_violate_safety_margin',
#   'ending_time': 680.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 181.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 554.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 181.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 530.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 182.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 529.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 182.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 528.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 183.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 528.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 183.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 528.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 184.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 528.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 184.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 530.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 185.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 533.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 185.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 535.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 186.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 539.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 186.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 546.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 187.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 544.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 187.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 546.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 188.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 551.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 188.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 574.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 189.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 581.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 189.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 586.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 190.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 590.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 190.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 594.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 191.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 584.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 191.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 591.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 192.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 601.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 192.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 615.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 193.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 616.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 193.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 621.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 194.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 635.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 194.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 650.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 195.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 661.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 195.5,
#   'worst_violation': 'did_crash',
#   'ending_time': 678.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 196.0,
#   'worst_violation': 'did_crash',
#   'ending_time': 692.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 196.5,
#   'worst_violation': '',
#   'ending_time': 696.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 197.0,
#   'worst_violation': '',
#   'ending_time': 697.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 197.5,
#   'worst_violation': '',
#   'ending_time': 697.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 198.0,
#   'worst_violation': '',
#   'ending_time': 698.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 198.5,
#   'worst_violation': '',
#   'ending_time': 698.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 199.0,
# ...
#   'starting_time': 431.0,
#   'worst_violation': '',
#   'ending_time': 931.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 431.5,
#   'worst_violation': '',
#   'ending_time': 931.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 432.0,
#   'worst_violation': '',
#   'ending_time': 932.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 432.5,
#   'worst_violation': '',
#   'ending_time': 932.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 433.0,
#   'worst_violation': '',
#   'ending_time': 933.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 433.5,
#   'worst_violation': '',
#   'ending_time': 933.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 434.0,
#   'worst_violation': '',
#   'ending_time': 934.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 434.5,
#   'worst_violation': '',
#   'ending_time': 934.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 435.0,
#   'worst_violation': '',
#   'ending_time': 935.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 435.5,
#   'worst_violation': '',
#   'ending_time': 935.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 436.0,
#   'worst_violation': '',
#   'ending_time': 936.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 436.5,
#   'worst_violation': '',
#   'ending_time': 936.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 437.0,
#   'worst_violation': '',
#   'ending_time': 937.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 437.5,
#   'worst_violation': '',
#   'ending_time': 937.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 438.0,
#   'worst_violation': '',
#   'ending_time': 938.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 438.5,
#   'worst_violation': '',
#   'ending_time': 938.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 439.0,
#   'worst_violation': '',
#   'ending_time': 939.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 439.5,
#   'worst_violation': '',
#   'ending_time': 939.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 440.0,
#   'worst_violation': '',
#   'ending_time': 940.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 440.5,
#   'worst_violation': '',
#   'ending_time': 940.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 441.0,
#   'worst_violation': '',
#   'ending_time': 941.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 441.5,
#   'worst_violation': '',
#   'ending_time': 941.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 442.0,
#   'worst_violation': '',
#   'ending_time': 942.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 442.5,
#   'worst_violation': '',
#   'ending_time': 942.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 443.0,
#   'worst_violation': '',
#   'ending_time': 943.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 443.5,
#   'worst_violation': '',
#   'ending_time': 943.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 444.0,
#   'worst_violation': '',
#   'ending_time': 944.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 444.5,
#   'worst_violation': '',
#   'ending_time': 944.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 445.0,
#   'worst_violation': '',
#   'ending_time': 945.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 445.5,
#   'worst_violation': '',
#   'ending_time': 945.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 446.0,
#   'worst_violation': '',
#   'ending_time': 946.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 446.5,
#   'worst_violation': '',
#   'ending_time': 946.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 447.0,
#   'worst_violation': '',
#   'ending_time': 947.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 447.5,
#   'worst_violation': '',
#   'ending_time': 947.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 448.0,
#   'worst_violation': '',
#   'ending_time': 948.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 448.5,
#   'worst_violation': '',
#   'ending_time': 948.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 449.0,
#   'worst_violation': '',
#   'ending_time': 949.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 449.5,
#   'worst_violation': '',
#   'ending_time': 949.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 450.0,
#   'worst_violation': '',
#   'ending_time': 950.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 450.5,
#   'worst_violation': '',
#   'ending_time': 950.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 451.0,
#   'worst_violation': '',
#   'ending_time': 951.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 451.5,
#   'worst_violation': '',
#   'ending_time': 951.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 452.0,
#   'worst_violation': '',
#   'ending_time': 952.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 452.5,
#   'worst_violation': '',
#   'ending_time': 952.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 453.0,
#   'worst_violation': '',
#   'ending_time': 953.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 453.5,
#   'worst_violation': '',
#   'ending_time': 953.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 454.0,
#   'worst_violation': '',
#   'ending_time': 954.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 454.5,
#   'worst_violation': '',
#   'ending_time': 954.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 455.0,
#   'worst_violation': '',
#   'ending_time': 955.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 455.5,
#   'worst_violation': '',
#   'ending_time': 955.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 456.0,
#   'worst_violation': '',
#   'ending_time': 956.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 456.5,
#   'worst_violation': '',
#   'ending_time': 956.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 457.0,
#   'worst_violation': '',
#   'ending_time': 957.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 457.5,
#   'worst_violation': '',
#   'ending_time': 957.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 458.0,
#   'worst_violation': '',
#   'ending_time': 958.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 458.5,
#   'worst_violation': '',
#   'ending_time': 958.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 459.0,
#   'worst_violation': '',
#   'ending_time': 959.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 459.5,
#   'worst_violation': '',
#   'ending_time': 959.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 460.0,
#   'worst_violation': '',
#   'ending_time': 960.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 460.5,
#   'worst_violation': '',
#   'ending_time': 960.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 461.0,
#   'worst_violation': '',
#   'ending_time': 961.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 461.5,
#   'worst_violation': '',
#   'ending_time': 961.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 462.0,
#   'worst_violation': '',
#   'ending_time': 962.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 462.5,
#   'worst_violation': '',
#   'ending_time': 962.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 463.0,
#   'worst_violation': '',
#   'ending_time': 963.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 463.5,
#   'worst_violation': '',
#   'ending_time': 963.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 464.0,
#   'worst_violation': '',
#   'ending_time': 964.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 464.5,
#   'worst_violation': '',
#   'ending_time': 964.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 465.0,
#   'worst_violation': '',
#   'ending_time': 965.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 465.5,
#   'worst_violation': '',
#   'ending_time': 965.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 466.0,
#   'worst_violation': '',
#   'ending_time': 966.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 466.5,
#   'worst_violation': '',
#   'ending_time': 966.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 467.0,
#   'worst_violation': '',
#   'ending_time': 967.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 467.5,
#   'worst_violation': '',
#   'ending_time': 967.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 468.0,
#   'worst_violation': '',
#   'ending_time': 968.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 468.5,
#   'worst_violation': '',
#   'ending_time': 968.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 469.0,
#   'worst_violation': '',
#   'ending_time': 969.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 469.5,
#   'worst_violation': '',
#   'ending_time': 969.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 470.0,
#   'worst_violation': '',
#   'ending_time': 970.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 470.5,
#   'worst_violation': '',
#   'ending_time': 970.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 471.0,
#   'worst_violation': '',
#   'ending_time': 971.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 471.5,
#   'worst_violation': '',
#   'ending_time': 971.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 472.0,
#   'worst_violation': '',
#   'ending_time': 972.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 472.5,
#   'worst_violation': '',
#   'ending_time': 972.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 473.0,
#   'worst_violation': '',
#   'ending_time': 973.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 473.5,
#   'worst_violation': '',
#   'ending_time': 973.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 474.0,
#   'worst_violation': '',
#   'ending_time': 974.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 474.5,
#   'worst_violation': '',
#   'ending_time': 974.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 475.0,
#   'worst_violation': '',
#   'ending_time': 975.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 475.5,
#   'worst_violation': '',
#   'ending_time': 975.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 476.0,
#   'worst_violation': '',
#   'ending_time': 976.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 476.5,
#   'worst_violation': '',
#   'ending_time': 976.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 477.0,
#   'worst_violation': '',
#   'ending_time': 977.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 477.5,
#   'worst_violation': '',
#   'ending_time': 977.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 478.0,
#   'worst_violation': '',
#   'ending_time': 978.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 478.5,
#   'worst_violation': '',
#   'ending_time': 978.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 479.0,
#   'worst_violation': '',
#   'ending_time': 979.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 479.5,
#   'worst_violation': '',
#   'ending_time': 979.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 480.0,
#   'worst_violation': '',
#   'ending_time': 980.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 480.5,
#   'worst_violation': '',
#   'ending_time': 980.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 481.0,
#   'worst_violation': '',
#   'ending_time': 981.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 481.5,
#   'worst_violation': '',
#   'ending_time': 981.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 482.0,
#   'worst_violation': '',
#   'ending_time': 982.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 482.5,
#   'worst_violation': '',
#   'ending_time': 982.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 483.0,
#   'worst_violation': '',
#   'ending_time': 983.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 483.5,
#   'worst_violation': '',
#   'ending_time': 983.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 484.0,
#   'worst_violation': '',
#   'ending_time': 984.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 484.5,
#   'worst_violation': '',
#   'ending_time': 984.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 485.0,
#   'worst_violation': '',
#   'ending_time': 985.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 485.5,
#   'worst_violation': '',
#   'ending_time': 985.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 486.0,
#   'worst_violation': '',
#   'ending_time': 986.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 486.5,
#   'worst_violation': '',
#   'ending_time': 986.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 487.0,
#   'worst_violation': '',
#   'ending_time': 987.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 487.5,
#   'worst_violation': '',
#   'ending_time': 987.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 488.0,
#   'worst_violation': '',
#   'ending_time': 988.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 488.5,
#   'worst_violation': '',
#   'ending_time': 988.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 489.0,
#   'worst_violation': '',
#   'ending_time': 989.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 489.5,
#   'worst_violation': '',
#   'ending_time': 989.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 490.0,
#   'worst_violation': '',
#   'ending_time': 990.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 490.5,
#   'worst_violation': '',
#   'ending_time': 990.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 491.0,
#   'worst_violation': '',
#   'ending_time': 991.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 491.5,
#   'worst_violation': '',
#   'ending_time': 991.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 492.0,
#   'worst_violation': '',
#   'ending_time': 992.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 492.5,
#   'worst_violation': '',
#   'ending_time': 992.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 493.0,
#   'worst_violation': '',
#   'ending_time': 993.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 493.5,
#   'worst_violation': '',
#   'ending_time': 993.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 494.0,
#   'worst_violation': '',
#   'ending_time': 994.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 494.5,
#   'worst_violation': '',
#   'ending_time': 994.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 495.0,
#   'worst_violation': '',
#   'ending_time': 995.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 495.5,
#   'worst_violation': '',
#   'ending_time': 995.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 496.0,
#   'worst_violation': '',
#   'ending_time': 996.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 496.5,
#   'worst_violation': '',
#   'ending_time': 996.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 497.0,
#   'worst_violation': '',
#   'ending_time': 997.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 497.5,
#   'worst_violation': '',
#   'ending_time': 997.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 498.0,
#   'worst_violation': '',
#   'ending_time': 998.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 498.5,
#   'worst_violation': '',
#   'ending_time': 998.5},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 499.0,
#   'worst_violation': '',
#   'ending_time': 999.0},
#  {'failure_mode': 'FM4: Rudder Freeze',
#   'starting_time': 499.5,
#   'worst_violation': '',
#   'ending_time': 999.5},
#  ...]
