# %%
import route_following_simulation as file
import sys
sys.path.append('/Users/ludvigloite/projects/skole/prosjektoppgave/ship_simulator/')

import matplotlib.pyplot as plt
import numpy as np

from models import ShipModel, ShipConfiguration, EnvironmentConfiguration, \
    MachinerySystemConfiguration, SimulationConfiguration, StaticObstacle, \
    MachineryMode, MachineryModeParams, MachineryModes, ThrottleControllerGains, \
    EngineThrottleFromSpeedSetPoint, HeadingByRouteController, HeadingControllerGains, \
    SpecificFuelConsumptionWartila6L26, SpecificFuelConsumptionBaudouin6M26Dot3, LosParameters, \
    SeachartSimulationConfiguration

import pandas as pd
import shapely.geometry as geo
from random import random
from tqdm import tqdm

failure_modes= ['FM1: Full Blackout', 'FM2: 80% Power Loss', 'FM3: 50% Power Loss', 'FM4: Rudder Freeze']
probabilities = {'FM1: Full Blackout':0.0001, 'FM2: 80% Power Loss':0.0002, 'FM3: 50% Power Loss':0.0003, 'FM4: Rudder Freeze':0.001}
reductionFactor = 500

#TODO: Mistenker at throttle control ikke funker. Vet ikke helt med rudder heller. Problemer med integratoren!
#TODO: Motor shaft speed og rudder har ufysiske raske endringer

simulation_locations = ["hestholmen_east", "hestholmen_west", "tautra_north_1", "tautra_north_2", "tautra_north_3","tautra_south_1", "tautra_south_2", "tautra_south_3"]
simulation_location = simulation_locations[5]
sim_location = "tautra"
#simulation_locations_used = simulation_locations[4:5]
simulation_locations_used = [i for i in simulation_locations if sim_location in i]

nu_of_simulations = 100

draft_of_ship = 6 #Typical draft around 6m: https://horizonship.com/ship/80m-dp2-platform-supply-vessel-1-of-3-sister-ships-2020-dwt-3500/
safety_margin = 50

show_seacharts = False
show_plots = False
save_results_to_csv = False

save_risky_result_svg = False
risky_result_svg_name = ''

simulation_data = {}

simulation_data[simulation_location] = {}
simulation_data[simulation_location]["consequence"] = []

# %%
route_txt = "route_seacharts.txt"
init_north_pos = 6955000
init_east_pos = 33100
size_map_east = 18000
size_map_north = 10124
center_map_east = 36580
center_map_north = 6960000
init_yaw_angle = 90 * np.pi / 180

new_data= False
route_txt = 'route_'+simulation_location+'.txt'


if simulation_location.split('_')[0] == "hestholmen":
    init_north_pos = 6993973
    init_east_pos = 75678
    size_map_east = 18000
    size_map_north = 10124
    center_map_east = 74826
    center_map_north = 6989614
    init_yaw_angle = 180 * np.pi / 180
elif simulation_location.split('_')[0] == "tautra":
    init_north_pos = 6974308
    init_east_pos = 81150
    size_map_east = 18000
    size_map_north = 10124
    center_map_east = 85814
    center_map_north = 6974797
    init_yaw_angle = 90 * np.pi / 180



main_engine_capacity = 2160e3
diesel_gen_capacity = 510e3
hybrid_shaft_gen_as_generator = 'GEN'
hybrid_shaft_gen_as_motor = 'MOTOR'
hybrid_shaft_gen_as_offline = 'OFF'

time_step = 0.5

env_config = EnvironmentConfiguration(
    current_velocity_component_from_north=-2,#-2,
    current_velocity_component_from_east=2,#-2,
    wind_speed=15,#15,
    wind_direction=0
)

seacharts_setup = SeachartSimulationConfiguration(
    size_of_map_east = size_map_east,
    size_of_map_north = size_map_north,
    center_of_map_east = center_map_east,
    center_of_map_north = center_map_north,
    database_file_names = ['More_og_Romsdal.gdb'],
    new_data = new_data,
    border = True,
    route_txt = route_txt,
    waypoint_color = 'green',
    draft_of_ship = draft_of_ship, #Typical draft around 6m: https://horizonship.com/ship/80m-dp2-platform-supply-vessel-1-of-3-sister-ships-2020-dwt-3500/
    safety_margin = safety_margin,
    wind_arrow_drawing_coefficient = 20,
    current_arrow_drawing_coefficient = 1000,
    current_wind_arrow_offset = 500,
    wind_arrow_color = 'black',
    current_arrow_color = 'yellow',
    able_to_crash = False
)

# %%
ship_config = ShipConfiguration(
    coefficient_of_deadweight_to_displacement=0.7,
    bunkers=200000,
    ballast=200000,
    length_of_ship=80,
    width_of_ship=16,
    added_mass_coefficient_in_surge=0.4,
    added_mass_coefficient_in_sway=0.4,
    added_mass_coefficient_in_yaw=0.4,
    dead_weight_tonnage=3850000,
    mass_over_linear_friction_coefficient_in_surge=130,
    mass_over_linear_friction_coefficient_in_sway=18,
    mass_over_linear_friction_coefficient_in_yaw=90,
    nonlinear_friction_coefficient__in_surge=2400,
    nonlinear_friction_coefficient__in_sway=4000,
    nonlinear_friction_coefficient__in_yaw=400
)
mec_mode_params = MachineryModeParams(
    main_engine_capacity=main_engine_capacity,
    electrical_capacity=diesel_gen_capacity,
    shaft_generator_state=hybrid_shaft_gen_as_offline
)
mec_mode = MachineryMode(params=mec_mode_params)
mso_modes = MachineryModes(
    [mec_mode]
)
fuel_spec_me = SpecificFuelConsumptionWartila6L26()
fuel_spec_dg = SpecificFuelConsumptionBaudouin6M26Dot3()
machinery_config = MachinerySystemConfiguration(
    machinery_modes=mso_modes,
    machinery_operating_mode=0,
    linear_friction_main_engine=68,
    linear_friction_hybrid_shaft_generator=57,
    gear_ratio_between_main_engine_and_propeller=0.6,
    gear_ratio_between_hybrid_shaft_generator_and_propeller=0.6,
    propeller_inertia=6000,
    propeller_diameter=3.1,
    propeller_speed_to_torque_coefficient=7.5,
    propeller_speed_to_thrust_force_coefficient=1.7,
    hotel_load=200000,
    rated_speed_main_engine_rpm=1000,
    rudder_angle_to_sway_force_coefficient=50e3,
    rudder_angle_to_yaw_force_coefficient=500e3,
    max_rudder_angle_degrees=30,
    specific_fuel_consumption_coefficients_me=fuel_spec_me.fuel_consumption_coefficients(),
    specific_fuel_consumption_coefficients_dg=fuel_spec_dg.fuel_consumption_coefficients()
)
simulation_setup = SimulationConfiguration(
    initial_north_position_m= init_north_pos, #6955000,#6958000,
    initial_east_position_m= init_east_pos, #33100,#30000,
    initial_yaw_angle_rad=init_yaw_angle, #90 * np.pi / 180, #90 * np.pi / 180,
    initial_forward_speed_m_per_s=7,
    initial_sideways_speed_m_per_s=0,
    initial_yaw_rate_rad_per_s=0,
    integration_step=time_step,
    simulation_time=1200,#1500,#600,
)

# %%
ship_model = ShipModel(ship_config=ship_config,
                    machinery_config=machinery_config,
                    environment_config=env_config,
                    seachart_config=seacharts_setup,
                    simulation_config=simulation_setup,
                    initial_propeller_shaft_speed_rad_per_s=400 * np.pi / 30)

desired_forward_speed_meters_per_second = 8.5
meters_between_each_failure_simulation = 20
time_since_last_ship_drawing = 30
duration_of_failure_seconds = 100
duration_of_failure_simulation_seconds = 100

failure_simulation_time_interval = int(meters_between_each_failure_simulation / (desired_forward_speed_meters_per_second*time_step))


# Set up control systems
throttle_controller_gains = ThrottleControllerGains(
    kp_ship_speed=7, ki_ship_speed=0.13, kp_shaft_speed=0.05, ki_shaft_speed=0.005
)
throttle_controller = EngineThrottleFromSpeedSetPoint(
    gains=throttle_controller_gains,
    max_shaft_speed=ship_model.ship_machinery_model.shaft_speed_max,
    time_step=time_step,
    initial_shaft_speed_integral_error=114
)

heading_controller_gains = HeadingControllerGains(kp=4, kd=90, ki=0.01)
los_guidance_parameters = LosParameters(
    radius_of_acceptance=200,
    lookahead_distance=500,
    integral_gain=0.002,
    integrator_windup_limit=4000
)
auto_pilot = HeadingByRouteController(
    route_name=route_txt,
    heading_controller_gains=heading_controller_gains,
    los_parameters=los_guidance_parameters,
    time_step=time_step,
    max_rudder_angle=machinery_config.max_rudder_angle_degrees * np.pi/180
)

ship_color = 'orange'

integrator_term = []
times = []
failures = []

colors = {'FM1: Full Blackout':'red', 'FM2: 80% Power Loss':'green', 'FM3: 50% Power Loss':'yellow', 'FM4: Rudder Freeze':'black'}

pbar = tqdm(total=1200)

while ship_model.int.time < ship_model.int.sim_time and auto_pilot.next_wpt != auto_pilot.prev_wpt:
    pbar.update(time_step)

    # Measure position and speed
    north_position = ship_model.north
    east_position = ship_model.east
    heading = ship_model.yaw_angle
    speed = ship_model.forward_speed

    

    # Find appropriate rudder angle and engine throttle
    rudder_angle = auto_pilot.rudder_angle_from_route(
        north_position=north_position,
        east_position=east_position,
        heading=heading
    )

    throttle = throttle_controller.throttle(
        speed_set_point=desired_forward_speed_meters_per_second,
        measured_speed=speed,
        measured_shaft_speed=speed
    )
    
    #FM1: Full Blackout':0.0001
    #print("time_interval: "+str(failure_simulation_time_interval))
    #print(ship_model.int.time % failure_simulation_time_interval)
        
    if ship_model.int.time % failure_simulation_time_interval == 0:
        throttle_controller, auto_pilot, failures = ship_model.simulate_failure(failure_type='FM1: Full Blackout', nu_of_timesteps=duration_of_failure_simulation_seconds, failure_time_length=duration_of_failure_seconds, auto_pilot=auto_pilot, throttle_controller=throttle_controller, desired_forward_speed_meters_per_second=desired_forward_speed_meters_per_second, ship_color=colors['FM1: Full Blackout'], rudder_angle=rudder_angle, throttle=throttle, failures=failures, printAllFailures=False)
        
    # Consequence Level Evaluation
    ship_color = 'white'

    position = geo.Point(east_position,north_position)
    dist_land = position.distance(ship_model.landGeometry)
    dist_shore = position.distance(ship_model.shoreGeometry)

    minimum_distance_to_hazard = min(dist_land, dist_shore)

    for i in range(len(ship_model.depths)):
        if ship_model.depths[i] <= ship_model.draft_of_ship:
            dist_seabed = position.distance(ship_model.seabedList[ship_model.depths[i]])
            if dist_seabed < minimum_distance_to_hazard:
                minimum_distance_to_hazard = dist_seabed

    if minimum_distance_to_hazard <= ship_model.safety_margin:
        ship_color = 'orange'
    if minimum_distance_to_hazard == 0 and ship_model.able_to_crash:
        ship_model.add_vessel_drawing(east_position=east_position, north_position=north_position, heading=heading, ship_color=ship_color)
        ship_model.enc.draw_circle((east_position,north_position), 50, 'red', thickness=10, fill=False)
        break

    # Update and integrate differential equations for current time step
    ship_model.store_simulation_data(throttle, rudder_angle)

    ship_model.update_differentials(engine_throttle=throttle, rudder_angle=rudder_angle)
    ship_model.integrate_differentials()

    integrator_term.append(auto_pilot.navigate.e_ct_int)
    times.append(ship_model.int.time)

    # Make a drawing of the ship from above every 20 second
    if time_since_last_ship_drawing > 30 or auto_pilot.next_wpt == auto_pilot.prev_wpt:
        ship_model.add_vessel_drawing(east_position=east_position, north_position=north_position, heading=heading, ship_color=ship_color)
        ship_model.ship_snap_shot()
        time_since_last_ship_drawing = 0
    time_since_last_ship_drawing += ship_model.int.dt
    # Progress time variable to the next time step
    ship_model.int.next_time()
    
pbar.close()
# Out:
#  88%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                  | 1053.5/1200 [00:33<00:04, 31.75it/s]

# %%
print(ship_model.int.time)
print(len(ship_model.simulation_results['fuel consumption [kg]']))
print(ship_model.simulation_results['fuel consumption [kg]'][-1])

# nontight
# 1139.5
# 3236.4979817530843

# tight
# 1053.5
# 2822.99172426093

# 1058.0
# 40728.348140069495

# 1053.5
# 100.96212817262634

# 1053.5
# 83.12556720114925
# Out:
# 1053.5
# 2107
# 83.12556720114925

# %%
ship_model.enc.add_vessels(*ship_model.ship_positions)
ship_model.draw_wind_and_current_arrows()
ship_model.enc.show_display()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 ship_model.enc.add_vessels(*ship_model.ship_positions)
#       2 ship_model.draw_wind_and_current_arrows()
# ----> 3 ship_model.enc.show_display()
#
# File ~/opt/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/seacharts/seacharts.py:266, in ENC.show_display(self, duration)
#     260 def show_display(self, duration: float = 0.0) -> None:
#     261     """
#     262     Show a Matplotlib display window of a maritime environment.
#     263     :param duration: optional int for window pause duration
#     264     :return: None
#     265     """
# --> 266     self._display.show(duration)
#
# File ~/opt/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/seacharts/display/display.py:239, in Display.show(self, duration)
#     237         self.features.update_hazards()
#     238 try:
# --> 239     plt.pause(duration)
#     240 except tk.TclError:
#     241     plt.close()
#
# File ~/opt/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/matplotlib/pyplot.py:548, in pause(interval)
#     546         canvas.draw_idle()
#     547     show(block=False)
# --> 548     canvas.start_event_loop(interval)
#     549 else:
#     550     time.sleep(interval)
#
# File ~/opt/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/matplotlib/backends/_backend_tk.py:381, in FigureCanvasTk.start_event_loop(self, timeout)
#     378     else:
#     379         self._event_loop_id = self._tkcanvas.after_idle(
#     380             self.stop_event_loop)
# --> 381 self._tkcanvas.mainloop()
#
# File ~/opt/anaconda3/envs/pygeospatial/lib/python3.9/tkinter/__init__.py:1429, in Misc.mainloop(self, n)
#    1427 def mainloop(self, n=0):
#    1428     """Call the mainloop of Tk."""
# -> 1429     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %%
#print(ship_model.consequence_dicts)
total_consequence = 0
for element in ship_model.consequence_dicts:
    for key, value in element.items():
        if key=='worst_violation' and value=='did_crash':
            total_consequence += 3
        elif key=='worst_violation' and value=='did_violate_safety_margin':
            total_consequence += 1

# %%
total_consequence
# Out:
# 0

# %%
ship_model.consequence_dicts
# Out:
# [{'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 0.0,
#   'worst_violation': '',
#   'ending_time': 100.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 4.0,
#   'worst_violation': '',
#   'ending_time': 104.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 8.0,
#   'worst_violation': '',
#   'ending_time': 108.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 12.0,
#   'worst_violation': '',
#   'ending_time': 112.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 16.0,
#   'worst_violation': '',
#   'ending_time': 116.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 20.0,
#   'worst_violation': '',
#   'ending_time': 120.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 24.0,
#   'worst_violation': '',
#   'ending_time': 124.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 28.0,
#   'worst_violation': '',
#   'ending_time': 128.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 32.0,
#   'worst_violation': '',
#   'ending_time': 132.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 36.0,
#   'worst_violation': '',
#   'ending_time': 136.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 40.0,
#   'worst_violation': '',
#   'ending_time': 140.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 44.0,
#   'worst_violation': '',
#   'ending_time': 144.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 48.0,
#   'worst_violation': '',
#   'ending_time': 148.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 52.0,
#   'worst_violation': '',
#   'ending_time': 152.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 56.0,
#   'worst_violation': '',
#   'ending_time': 156.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 60.0,
#   'worst_violation': '',
#   'ending_time': 160.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 64.0,
#   'worst_violation': '',
#   'ending_time': 164.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 68.0,
#   'worst_violation': '',
#   'ending_time': 168.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 72.0,
#   'worst_violation': '',
#   'ending_time': 172.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 76.0,
#   'worst_violation': '',
#   'ending_time': 176.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 80.0,
#   'worst_violation': '',
#   'ending_time': 180.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 84.0,
#   'worst_violation': '',
#   'ending_time': 184.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 88.0,
#   'worst_violation': '',
#   'ending_time': 188.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 92.0,
#   'worst_violation': '',
#   'ending_time': 192.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 96.0,
#   'worst_violation': '',
#   'ending_time': 196.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 100.0,
#   'worst_violation': '',
#   'ending_time': 200.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 104.0,
#   'worst_violation': '',
#   'ending_time': 204.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 108.0,
#   'worst_violation': '',
#   'ending_time': 208.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 112.0,
#   'worst_violation': '',
#   'ending_time': 212.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 116.0,
#   'worst_violation': '',
#   'ending_time': 216.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 120.0,
#   'worst_violation': '',
#   'ending_time': 220.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 124.0,
#   'worst_violation': '',
#   'ending_time': 224.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 128.0,
#   'worst_violation': '',
#   'ending_time': 228.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 132.0,
#   'worst_violation': '',
#   'ending_time': 232.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 136.0,
#   'worst_violation': '',
#   'ending_time': 236.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 140.0,
#   'worst_violation': '',
#   'ending_time': 240.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 144.0,
#   'worst_violation': '',
#   'ending_time': 244.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 148.0,
#   'worst_violation': '',
#   'ending_time': 248.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 152.0,
#   'worst_violation': '',
#   'ending_time': 252.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 156.0,
#   'worst_violation': '',
#   'ending_time': 256.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 160.0,
#   'worst_violation': '',
#   'ending_time': 260.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 164.0,
#   'worst_violation': '',
#   'ending_time': 264.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 168.0,
#   'worst_violation': '',
#   'ending_time': 268.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 172.0,
#   'worst_violation': '',
#   'ending_time': 272.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 176.0,
#   'worst_violation': '',
#   'ending_time': 276.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 180.0,
#   'worst_violation': '',
#   'ending_time': 280.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 184.0,
#   'worst_violation': '',
#   'ending_time': 284.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 188.0,
#   'worst_violation': '',
#   'ending_time': 288.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 192.0,
#   'worst_violation': '',
#   'ending_time': 292.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 196.0,
#   'worst_violation': '',
#   'ending_time': 296.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 200.0,
#   'worst_violation': '',
#   'ending_time': 300.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 204.0,
#   'worst_violation': '',
#   'ending_time': 304.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 208.0,
#   'worst_violation': '',
#   'ending_time': 308.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 212.0,
#   'worst_violation': '',
#   'ending_time': 312.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 216.0,
#   'worst_violation': '',
#   'ending_time': 316.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 220.0,
#   'worst_violation': '',
#   'ending_time': 320.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 224.0,
#   'worst_violation': '',
#   'ending_time': 324.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 228.0,
#   'worst_violation': '',
#   'ending_time': 328.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 232.0,
#   'worst_violation': '',
#   'ending_time': 332.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 236.0,
#   'worst_violation': '',
#   'ending_time': 336.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 240.0,
#   'worst_violation': '',
#   'ending_time': 340.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 244.0,
#   'worst_violation': '',
#   'ending_time': 344.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 248.0,
#   'worst_violation': '',
#   'ending_time': 348.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 252.0,
#   'worst_violation': '',
#   'ending_time': 352.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 256.0,
#   'worst_violation': '',
#   'ending_time': 356.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 260.0,
#   'worst_violation': '',
#   'ending_time': 360.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 264.0,
#   'worst_violation': '',
#   'ending_time': 364.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 268.0,
#   'worst_violation': '',
#   'ending_time': 368.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 272.0,
#   'worst_violation': '',
#   'ending_time': 372.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 276.0,
#   'worst_violation': '',
#   'ending_time': 376.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 280.0,
#   'worst_violation': '',
#   'ending_time': 380.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 284.0,
#   'worst_violation': '',
#   'ending_time': 384.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 288.0,
#   'worst_violation': '',
#   'ending_time': 388.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 292.0,
#   'worst_violation': '',
#   'ending_time': 392.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 296.0,
#   'worst_violation': '',
#   'ending_time': 396.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 300.0,
#   'worst_violation': '',
#   'ending_time': 400.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 304.0,
#   'worst_violation': '',
#   'ending_time': 404.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 308.0,
#   'worst_violation': '',
#   'ending_time': 408.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 312.0,
#   'worst_violation': '',
#   'ending_time': 412.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 316.0,
#   'worst_violation': '',
#   'ending_time': 416.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 320.0,
#   'worst_violation': '',
#   'ending_time': 420.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 324.0,
#   'worst_violation': '',
#   'ending_time': 424.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 328.0,
#   'worst_violation': '',
#   'ending_time': 428.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 332.0,
#   'worst_violation': '',
#   'ending_time': 432.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 336.0,
#   'worst_violation': '',
#   'ending_time': 436.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 340.0,
#   'worst_violation': '',
#   'ending_time': 440.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 344.0,
#   'worst_violation': '',
#   'ending_time': 444.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 348.0,
#   'worst_violation': '',
#   'ending_time': 448.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 352.0,
#   'worst_violation': '',
#   'ending_time': 452.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 356.0,
#   'worst_violation': '',
#   'ending_time': 456.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 360.0,
#   'worst_violation': '',
#   'ending_time': 460.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 364.0,
#   'worst_violation': '',
#   'ending_time': 464.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 368.0,
#   'worst_violation': '',
#   'ending_time': 468.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 372.0,
#   'worst_violation': '',
#   'ending_time': 472.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 376.0,
#   'worst_violation': '',
#   'ending_time': 476.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 380.0,
#   'worst_violation': '',
#   'ending_time': 480.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 384.0,
#   'worst_violation': '',
#   'ending_time': 484.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 388.0,
#   'worst_violation': '',
#   'ending_time': 488.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 392.0,
#   'worst_violation': '',
#   'ending_time': 492.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 396.0,
#   'worst_violation': '',
#   'ending_time': 496.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 400.0,
#   'worst_violation': '',
#   'ending_time': 500.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 404.0,
#   'worst_violation': '',
#   'ending_time': 504.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 408.0,
#   'worst_violation': '',
#   'ending_time': 508.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 412.0,
#   'worst_violation': '',
#   'ending_time': 512.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 416.0,
#   'worst_violation': '',
#   'ending_time': 516.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 420.0,
#   'worst_violation': '',
#   'ending_time': 520.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 424.0,
#   'worst_violation': '',
#   'ending_time': 524.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 428.0,
#   'worst_violation': '',
#   'ending_time': 528.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 432.0,
#   'worst_violation': '',
#   'ending_time': 532.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 436.0,
#   'worst_violation': '',
#   'ending_time': 536.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 440.0,
#   'worst_violation': '',
#   'ending_time': 540.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 444.0,
#   'worst_violation': '',
#   'ending_time': 544.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 448.0,
#   'worst_violation': '',
#   'ending_time': 548.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 452.0,
#   'worst_violation': '',
#   'ending_time': 552.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 456.0,
#   'worst_violation': '',
#   'ending_time': 556.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 460.0,
#   'worst_violation': '',
#   'ending_time': 560.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 464.0,
#   'worst_violation': '',
#   'ending_time': 564.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 468.0,
#   'worst_violation': '',
#   'ending_time': 568.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 472.0,
#   'worst_violation': '',
#   'ending_time': 572.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 476.0,
#   'worst_violation': '',
#   'ending_time': 576.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 480.0,
#   'worst_violation': '',
#   'ending_time': 580.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 484.0,
#   'worst_violation': '',
#   'ending_time': 584.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 488.0,
#   'worst_violation': '',
#   'ending_time': 588.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 492.0,
#   'worst_violation': '',
#   'ending_time': 592.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 496.0,
#   'worst_violation': '',
#   'ending_time': 596.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 500.0,
#   'worst_violation': '',
#   'ending_time': 600.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 504.0,
#   'worst_violation': '',
#   'ending_time': 604.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 508.0,
#   'worst_violation': '',
#   'ending_time': 608.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 512.0,
#   'worst_violation': '',
#   'ending_time': 612.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 516.0,
#   'worst_violation': '',
#   'ending_time': 616.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 520.0,
#   'worst_violation': '',
#   'ending_time': 620.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 524.0,
#   'worst_violation': '',
#   'ending_time': 624.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 528.0,
#   'worst_violation': '',
#   'ending_time': 628.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 532.0,
#   'worst_violation': '',
#   'ending_time': 632.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 536.0,
#   'worst_violation': '',
#   'ending_time': 636.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 540.0,
#   'worst_violation': '',
#   'ending_time': 640.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 544.0,
#   'worst_violation': '',
#   'ending_time': 644.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 548.0,
#   'worst_violation': '',
#   'ending_time': 648.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 552.0,
#   'worst_violation': '',
#   'ending_time': 652.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 556.0,
#   'worst_violation': '',
#   'ending_time': 656.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 560.0,
#   'worst_violation': '',
#   'ending_time': 660.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 564.0,
#   'worst_violation': '',
#   'ending_time': 664.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 568.0,
#   'worst_violation': '',
#   'ending_time': 668.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 572.0,
#   'worst_violation': '',
#   'ending_time': 672.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 576.0,
#   'worst_violation': '',
#   'ending_time': 676.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 580.0,
#   'worst_violation': '',
#   'ending_time': 680.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 584.0,
#   'worst_violation': '',
#   'ending_time': 684.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 588.0,
#   'worst_violation': '',
#   'ending_time': 688.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 592.0,
#   'worst_violation': '',
#   'ending_time': 692.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 596.0,
#   'worst_violation': '',
#   'ending_time': 696.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 600.0,
#   'worst_violation': '',
#   'ending_time': 700.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 604.0,
#   'worst_violation': '',
#   'ending_time': 704.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 608.0,
#   'worst_violation': '',
#   'ending_time': 708.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 612.0,
#   'worst_violation': '',
#   'ending_time': 712.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 616.0,
#   'worst_violation': '',
#   'ending_time': 716.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 620.0,
#   'worst_violation': '',
#   'ending_time': 720.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 624.0,
#   'worst_violation': '',
#   'ending_time': 724.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 628.0,
#   'worst_violation': '',
#   'ending_time': 728.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 632.0,
#   'worst_violation': '',
#   'ending_time': 732.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 636.0,
#   'worst_violation': '',
#   'ending_time': 736.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 640.0,
#   'worst_violation': '',
#   'ending_time': 740.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 644.0,
#   'worst_violation': '',
#   'ending_time': 744.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 648.0,
#   'worst_violation': '',
#   'ending_time': 748.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 652.0,
#   'worst_violation': '',
#   'ending_time': 752.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 656.0,
#   'worst_violation': '',
#   'ending_time': 756.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 660.0,
#   'worst_violation': '',
#   'ending_time': 760.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 664.0,
#   'worst_violation': '',
#   'ending_time': 764.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 668.0,
#   'worst_violation': '',
#   'ending_time': 768.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 672.0,
#   'worst_violation': '',
#   'ending_time': 772.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 676.0,
#   'worst_violation': '',
#   'ending_time': 776.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 680.0,
#   'worst_violation': '',
#   'ending_time': 780.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 684.0,
#   'worst_violation': '',
#   'ending_time': 784.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 688.0,
#   'worst_violation': '',
#   'ending_time': 788.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 692.0,
#   'worst_violation': '',
#   'ending_time': 792.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 696.0,
#   'worst_violation': '',
#   'ending_time': 796.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 700.0,
#   'worst_violation': '',
#   'ending_time': 800.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 704.0,
#   'worst_violation': '',
#   'ending_time': 804.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 708.0,
#   'worst_violation': '',
#   'ending_time': 808.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 712.0,
#   'worst_violation': '',
#   'ending_time': 812.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 716.0,
#   'worst_violation': '',
#   'ending_time': 816.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 720.0,
#   'worst_violation': '',
#   'ending_time': 820.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 724.0,
#   'worst_violation': '',
#   'ending_time': 824.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 728.0,
#   'worst_violation': '',
#   'ending_time': 828.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 732.0,
#   'worst_violation': '',
#   'ending_time': 832.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 736.0,
#   'worst_violation': '',
#   'ending_time': 836.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 740.0,
#   'worst_violation': '',
#   'ending_time': 840.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 744.0,
#   'worst_violation': '',
#   'ending_time': 844.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 748.0,
#   'worst_violation': '',
#   'ending_time': 848.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 752.0,
#   'worst_violation': '',
#   'ending_time': 852.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 756.0,
#   'worst_violation': '',
#   'ending_time': 856.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 760.0,
#   'worst_violation': '',
#   'ending_time': 860.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 764.0,
#   'worst_violation': '',
#   'ending_time': 864.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 768.0,
#   'worst_violation': '',
#   'ending_time': 868.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 772.0,
#   'worst_violation': '',
#   'ending_time': 872.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 776.0,
#   'worst_violation': '',
#   'ending_time': 876.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 780.0,
#   'worst_violation': '',
#   'ending_time': 880.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 784.0,
#   'worst_violation': '',
#   'ending_time': 884.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 788.0,
#   'worst_violation': '',
#   'ending_time': 888.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 792.0,
#   'worst_violation': '',
#   'ending_time': 892.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 796.0,
#   'worst_violation': '',
#   'ending_time': 896.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 800.0,
#   'worst_violation': '',
#   'ending_time': 900.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 804.0,
#   'worst_violation': '',
#   'ending_time': 904.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 808.0,
#   'worst_violation': '',
#   'ending_time': 908.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 812.0,
#   'worst_violation': '',
#   'ending_time': 912.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 816.0,
#   'worst_violation': '',
#   'ending_time': 916.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 820.0,
#   'worst_violation': '',
#   'ending_time': 920.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 824.0,
#   'worst_violation': '',
#   'ending_time': 924.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 828.0,
#   'worst_violation': '',
#   'ending_time': 928.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 832.0,
#   'worst_violation': '',
#   'ending_time': 932.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 836.0,
#   'worst_violation': '',
#   'ending_time': 936.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 840.0,
#   'worst_violation': '',
#   'ending_time': 940.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 844.0,
#   'worst_violation': '',
#   'ending_time': 944.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 848.0,
#   'worst_violation': '',
#   'ending_time': 948.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 852.0,
#   'worst_violation': '',
#   'ending_time': 952.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 856.0,
#   'worst_violation': '',
#   'ending_time': 956.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 860.0,
#   'worst_violation': '',
#   'ending_time': 960.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 864.0,
#   'worst_violation': '',
#   'ending_time': 964.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 868.0,
#   'worst_violation': '',
#   'ending_time': 968.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 872.0,
#   'worst_violation': '',
#   'ending_time': 972.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 876.0,
#   'worst_violation': '',
#   'ending_time': 976.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 880.0,
#   'worst_violation': '',
#   'ending_time': 980.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 884.0,
#   'worst_violation': '',
#   'ending_time': 984.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 888.0,
#   'worst_violation': '',
#   'ending_time': 988.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 892.0,
#   'worst_violation': '',
#   'ending_time': 992.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 896.0,
#   'worst_violation': '',
#   'ending_time': 996.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 900.0,
#   'worst_violation': '',
#   'ending_time': 1000.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 904.0,
#   'worst_violation': '',
#   'ending_time': 1004.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 908.0,
#   'worst_violation': '',
#   'ending_time': 1008.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 912.0,
#   'worst_violation': '',
#   'ending_time': 1012.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 916.0,
#   'worst_violation': '',
#   'ending_time': 1016.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 920.0,
#   'worst_violation': '',
#   'ending_time': 1020.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 924.0,
#   'worst_violation': '',
#   'ending_time': 1024.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 928.0,
#   'worst_violation': '',
#   'ending_time': 1028.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 932.0,
#   'worst_violation': '',
#   'ending_time': 1032.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 936.0,
#   'worst_violation': '',
#   'ending_time': 1036.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 940.0,
#   'worst_violation': '',
#   'ending_time': 1040.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 944.0,
#   'worst_violation': '',
#   'ending_time': 1044.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 948.0,
#   'worst_violation': '',
#   'ending_time': 1048.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 952.0,
#   'worst_violation': '',
#   'ending_time': 1052.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 956.0,
#   'worst_violation': '',
#   'ending_time': 1056.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 960.0,
#   'worst_violation': '',
#   'ending_time': 1060.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 964.0,
#   'worst_violation': '',
#   'ending_time': 1064.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 968.0,
#   'worst_violation': '',
#   'ending_time': 1068.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 972.0,
#   'worst_violation': '',
#   'ending_time': 1072.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 976.0,
#   'worst_violation': '',
#   'ending_time': 1076.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 980.0,
#   'worst_violation': '',
#   'ending_time': 1080.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 984.0,
#   'worst_violation': '',
#   'ending_time': 1084.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 988.0,
#   'worst_violation': '',
#   'ending_time': 1088.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 992.0,
#   'worst_violation': '',
#   'ending_time': 1092.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 996.0,
#   'worst_violation': '',
#   'ending_time': 1096.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 1000.0,
#   'worst_violation': '',
#   'ending_time': 1100.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 1004.0,
#   'worst_violation': '',
#   'ending_time': 1104.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 1008.0,
#   'worst_violation': '',
#   'ending_time': 1108.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 1012.0,
#   'worst_violation': '',
#   'ending_time': 1112.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 1016.0,
#   'worst_violation': '',
#   'ending_time': 1116.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 1020.0,
#   'worst_violation': '',
#   'ending_time': 1120.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 1024.0,
#   'worst_violation': '',
#   'ending_time': 1124.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 1028.0,
#   'worst_violation': '',
#   'ending_time': 1128.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 1032.0,
#   'worst_violation': '',
#   'ending_time': 1132.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 1036.0,
#   'worst_violation': '',
#   'ending_time': 1136.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 1040.0,
#   'worst_violation': '',
#   'ending_time': 1140.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 1044.0,
#   'worst_violation': '',
#   'ending_time': 1144.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 1048.0,
#   'worst_violation': '',
#   'ending_time': 1148.0},
#  {'failure_mode': 'FM1: Full Blackout',
#   'starting_time': 1052.0,
#   'worst_violation': '',
#   'ending_time': 1152.0}]

# %%
count_crash = 0
count_safety_margin = 0
for element in ship_model.consequence_dicts:
    #if element['failure_mode'] == 'FM1: Full Blackout':        
    if element['worst_violation']=='did_crash':
        count_crash += 1
    elif element['worst_violation']=='did_violate_safety_margin':
        count_safety_margin += 1
print("nu of crashes:", count_crash)
print("nu of safety margin: ",count_safety_margin)
#print("total failure simulations: 8480")
# Out:
# nu of crashes: 0
# nu of safety margin:  0

# %%
print(ship_model.int.time)
print(ship_model.simulation_results['fuel consumption [kg]'][-1])
# Out:
# 1053.5
# 83.12556720114925

# %%
print("Voyage "+simulation_location+" took "+str(ship_model.int.time/60)+" minutes. Fuel consumption was "+str(ship_model.simulation_results['fuel consumption [kg]'][-1])+" kg/$. Total consequence was "+str(total_consequence))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print("Voyage "+simulation_location+" took "+str(ship_model.int.time/60)+" minutes. Fuel consumption was "+str(ship_model.simulation_results['fuel consumption [kg]'][-1])+" kg/$. Total consequence was "+str(total_consequence))
#
# NameError: name 'total_consequence' is not defined

# %%
import pickle

# %%
result_dict = {}
result_dict['route'] = simulation_location
result_dict['duration_of_failure_seconds'] = duration_of_failure_seconds
result_dict['duration_of_failure_simulation_seconds'] = duration_of_failure_simulation_seconds
result_dict['fuel_consumption_kgs'] = ship_model.simulation_results['fuel consumption [kg]'][-1]
result_dict['time_usage_seconds'] = ship_model.int.time
result_dict['consequence_dicts'] = ship_model.consequence_dicts

folder_name='test_13_03_2023'

with open('reports/'+folder_name+'/'+'result_dict_'+str(simulation_location)+'_'+str(duration_of_failure_seconds)+'sec_'+str(duration_of_failure_simulation_seconds)+'sec.pkl', 'wb') as f:
    pickle.dump(result_dict, f)

# %%
with open('reports/'+folder_name+'/'+'result_dict_'+str(simulation_location)+'_'+str(duration_of_failure_seconds)+'sec_'+str(duration_of_failure_simulation_seconds)+'sec.pkl', 'rb') as f:
    loaded_dict = pickle.load(f)

# %%
loaded_dict
# Out:
# {'route': 'tautra_south_tight',
#  'duration_of_failure_seconds': 100,
#  'duration_of_failure_simulation_seconds': 100,
#  'fuel_consumption_kgs': 83.12556720114925,
#  'time_usage_seconds': 1053.5,
#  'consequence_dicts': [{'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 0.0,
#    'worst_violation': '',
#    'ending_time': 100.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 4.0,
#    'worst_violation': '',
#    'ending_time': 104.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 8.0,
#    'worst_violation': '',
#    'ending_time': 108.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 12.0,
#    'worst_violation': '',
#    'ending_time': 112.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 16.0,
#    'worst_violation': '',
#    'ending_time': 116.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 20.0,
#    'worst_violation': '',
#    'ending_time': 120.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 24.0,
#    'worst_violation': '',
#    'ending_time': 124.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 28.0,
#    'worst_violation': '',
#    'ending_time': 128.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 32.0,
#    'worst_violation': '',
#    'ending_time': 132.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 36.0,
#    'worst_violation': '',
#    'ending_time': 136.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 40.0,
#    'worst_violation': '',
#    'ending_time': 140.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 44.0,
#    'worst_violation': '',
#    'ending_time': 144.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 48.0,
#    'worst_violation': '',
#    'ending_time': 148.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 52.0,
#    'worst_violation': '',
#    'ending_time': 152.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 56.0,
#    'worst_violation': '',
#    'ending_time': 156.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 60.0,
#    'worst_violation': '',
#    'ending_time': 160.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 64.0,
#    'worst_violation': '',
#    'ending_time': 164.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 68.0,
#    'worst_violation': '',
#    'ending_time': 168.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 72.0,
#    'worst_violation': '',
#    'ending_time': 172.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 76.0,
#    'worst_violation': '',
#    'ending_time': 176.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 80.0,
#    'worst_violation': '',
#    'ending_time': 180.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 84.0,
#    'worst_violation': '',
#    'ending_time': 184.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 88.0,
#    'worst_violation': '',
#    'ending_time': 188.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 92.0,
#    'worst_violation': '',
#    'ending_time': 192.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 96.0,
#    'worst_violation': '',
#    'ending_time': 196.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 100.0,
#    'worst_violation': '',
#    'ending_time': 200.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 104.0,
#    'worst_violation': '',
#    'ending_time': 204.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 108.0,
#    'worst_violation': '',
#    'ending_time': 208.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 112.0,
#    'worst_violation': '',
#    'ending_time': 212.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 116.0,
#    'worst_violation': '',
#    'ending_time': 216.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 120.0,
#    'worst_violation': '',
#    'ending_time': 220.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 124.0,
#    'worst_violation': '',
#    'ending_time': 224.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 128.0,
#    'worst_violation': '',
#    'ending_time': 228.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 132.0,
#    'worst_violation': '',
#    'ending_time': 232.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 136.0,
#    'worst_violation': '',
#    'ending_time': 236.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 140.0,
#    'worst_violation': '',
#    'ending_time': 240.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 144.0,
#    'worst_violation': '',
#    'ending_time': 244.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 148.0,
#    'worst_violation': '',
#    'ending_time': 248.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 152.0,
#    'worst_violation': '',
#    'ending_time': 252.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 156.0,
#    'worst_violation': '',
#    'ending_time': 256.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 160.0,
#    'worst_violation': '',
#    'ending_time': 260.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 164.0,
#    'worst_violation': '',
#    'ending_time': 264.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 168.0,
#    'worst_violation': '',
#    'ending_time': 268.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 172.0,
#    'worst_violation': '',
#    'ending_time': 272.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 176.0,
#    'worst_violation': '',
#    'ending_time': 276.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 180.0,
#    'worst_violation': '',
#    'ending_time': 280.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 184.0,
#    'worst_violation': '',
#    'ending_time': 284.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 188.0,
#    'worst_violation': '',
#    'ending_time': 288.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 192.0,
#    'worst_violation': '',
#    'ending_time': 292.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 196.0,
#    'worst_violation': '',
#    'ending_time': 296.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 200.0,
#    'worst_violation': '',
#    'ending_time': 300.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 204.0,
#    'worst_violation': '',
#    'ending_time': 304.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 208.0,
#    'worst_violation': '',
#    'ending_time': 308.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 212.0,
#    'worst_violation': '',
#    'ending_time': 312.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 216.0,
#    'worst_violation': '',
#    'ending_time': 316.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 220.0,
#    'worst_violation': '',
#    'ending_time': 320.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 224.0,
#    'worst_violation': '',
#    'ending_time': 324.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 228.0,
#    'worst_violation': '',
#    'ending_time': 328.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 232.0,
#    'worst_violation': '',
#    'ending_time': 332.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 236.0,
#    'worst_violation': '',
#    'ending_time': 336.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 240.0,
#    'worst_violation': '',
#    'ending_time': 340.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 244.0,
#    'worst_violation': '',
#    'ending_time': 344.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 248.0,
#    'worst_violation': '',
#    'ending_time': 348.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 252.0,
#    'worst_violation': '',
#    'ending_time': 352.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 256.0,
#    'worst_violation': '',
#    'ending_time': 356.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 260.0,
#    'worst_violation': '',
#    'ending_time': 360.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 264.0,
#    'worst_violation': '',
#    'ending_time': 364.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 268.0,
#    'worst_violation': '',
#    'ending_time': 368.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 272.0,
#    'worst_violation': '',
#    'ending_time': 372.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 276.0,
#    'worst_violation': '',
#    'ending_time': 376.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 280.0,
#    'worst_violation': '',
#    'ending_time': 380.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 284.0,
#    'worst_violation': '',
#    'ending_time': 384.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 288.0,
#    'worst_violation': '',
#    'ending_time': 388.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 292.0,
#    'worst_violation': '',
#    'ending_time': 392.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 296.0,
#    'worst_violation': '',
#    'ending_time': 396.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 300.0,
#    'worst_violation': '',
#    'ending_time': 400.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 304.0,
#    'worst_violation': '',
#    'ending_time': 404.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 308.0,
#    'worst_violation': '',
#    'ending_time': 408.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 312.0,
#    'worst_violation': '',
#    'ending_time': 412.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 316.0,
#    'worst_violation': '',
#    'ending_time': 416.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 320.0,
#    'worst_violation': '',
#    'ending_time': 420.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 324.0,
#    'worst_violation': '',
#    'ending_time': 424.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 328.0,
#    'worst_violation': '',
#    'ending_time': 428.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 332.0,
#    'worst_violation': '',
#    'ending_time': 432.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 336.0,
#    'worst_violation': '',
#    'ending_time': 436.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 340.0,
#    'worst_violation': '',
#    'ending_time': 440.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 344.0,
#    'worst_violation': '',
#    'ending_time': 444.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 348.0,
#    'worst_violation': '',
#    'ending_time': 448.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 352.0,
#    'worst_violation': '',
#    'ending_time': 452.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 356.0,
#    'worst_violation': '',
#    'ending_time': 456.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 360.0,
#    'worst_violation': '',
#    'ending_time': 460.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 364.0,
#    'worst_violation': '',
#    'ending_time': 464.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 368.0,
#    'worst_violation': '',
#    'ending_time': 468.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 372.0,
#    'worst_violation': '',
#    'ending_time': 472.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 376.0,
#    'worst_violation': '',
#    'ending_time': 476.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 380.0,
#    'worst_violation': '',
#    'ending_time': 480.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 384.0,
#    'worst_violation': '',
#    'ending_time': 484.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 388.0,
#    'worst_violation': '',
#    'ending_time': 488.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 392.0,
#    'worst_violation': '',
#    'ending_time': 492.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 396.0,
#    'worst_violation': '',
#    'ending_time': 496.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 400.0,
#    'worst_violation': '',
#    'ending_time': 500.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 404.0,
#    'worst_violation': '',
#    'ending_time': 504.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 408.0,
#    'worst_violation': '',
#    'ending_time': 508.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 412.0,
#    'worst_violation': '',
#    'ending_time': 512.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 416.0,
#    'worst_violation': '',
#    'ending_time': 516.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 420.0,
#    'worst_violation': '',
#    'ending_time': 520.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 424.0,
#    'worst_violation': '',
#    'ending_time': 524.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 428.0,
#    'worst_violation': '',
#    'ending_time': 528.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 432.0,
#    'worst_violation': '',
#    'ending_time': 532.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 436.0,
#    'worst_violation': '',
#    'ending_time': 536.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 440.0,
#    'worst_violation': '',
#    'ending_time': 540.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 444.0,
#    'worst_violation': '',
#    'ending_time': 544.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 448.0,
#    'worst_violation': '',
#    'ending_time': 548.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 452.0,
#    'worst_violation': '',
#    'ending_time': 552.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 456.0,
#    'worst_violation': '',
#    'ending_time': 556.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 460.0,
#    'worst_violation': '',
#    'ending_time': 560.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 464.0,
#    'worst_violation': '',
#    'ending_time': 564.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 468.0,
#    'worst_violation': '',
#    'ending_time': 568.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 472.0,
#    'worst_violation': '',
#    'ending_time': 572.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 476.0,
#    'worst_violation': '',
#    'ending_time': 576.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 480.0,
#    'worst_violation': '',
#    'ending_time': 580.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 484.0,
#    'worst_violation': '',
#    'ending_time': 584.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 488.0,
#    'worst_violation': '',
#    'ending_time': 588.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 492.0,
#    'worst_violation': '',
#    'ending_time': 592.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 496.0,
#    'worst_violation': '',
#    'ending_time': 596.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 500.0,
#    'worst_violation': '',
#    'ending_time': 600.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 504.0,
#    'worst_violation': '',
#    'ending_time': 604.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 508.0,
#    'worst_violation': '',
#    'ending_time': 608.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 512.0,
#    'worst_violation': '',
#    'ending_time': 612.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 516.0,
#    'worst_violation': '',
#    'ending_time': 616.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 520.0,
#    'worst_violation': '',
#    'ending_time': 620.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 524.0,
#    'worst_violation': '',
#    'ending_time': 624.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 528.0,
#    'worst_violation': '',
#    'ending_time': 628.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 532.0,
#    'worst_violation': '',
#    'ending_time': 632.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 536.0,
#    'worst_violation': '',
#    'ending_time': 636.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 540.0,
#    'worst_violation': '',
#    'ending_time': 640.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 544.0,
#    'worst_violation': '',
#    'ending_time': 644.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 548.0,
#    'worst_violation': '',
#    'ending_time': 648.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 552.0,
#    'worst_violation': '',
#    'ending_time': 652.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 556.0,
#    'worst_violation': '',
#    'ending_time': 656.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 560.0,
#    'worst_violation': '',
#    'ending_time': 660.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 564.0,
#    'worst_violation': '',
#    'ending_time': 664.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 568.0,
#    'worst_violation': '',
#    'ending_time': 668.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 572.0,
#    'worst_violation': '',
#    'ending_time': 672.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 576.0,
#    'worst_violation': '',
#    'ending_time': 676.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 580.0,
#    'worst_violation': '',
#    'ending_time': 680.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 584.0,
#    'worst_violation': '',
#    'ending_time': 684.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 588.0,
#    'worst_violation': '',
#    'ending_time': 688.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 592.0,
#    'worst_violation': '',
#    'ending_time': 692.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 596.0,
#    'worst_violation': '',
#    'ending_time': 696.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 600.0,
#    'worst_violation': '',
#    'ending_time': 700.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 604.0,
#    'worst_violation': '',
#    'ending_time': 704.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 608.0,
#    'worst_violation': '',
#    'ending_time': 708.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 612.0,
#    'worst_violation': '',
#    'ending_time': 712.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 616.0,
#    'worst_violation': '',
#    'ending_time': 716.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 620.0,
#    'worst_violation': '',
#    'ending_time': 720.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 624.0,
#    'worst_violation': '',
#    'ending_time': 724.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 628.0,
#    'worst_violation': '',
#    'ending_time': 728.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 632.0,
#    'worst_violation': '',
#    'ending_time': 732.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 636.0,
#    'worst_violation': '',
#    'ending_time': 736.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 640.0,
#    'worst_violation': '',
#    'ending_time': 740.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 644.0,
#    'worst_violation': '',
#    'ending_time': 744.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 648.0,
#    'worst_violation': '',
#    'ending_time': 748.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 652.0,
#    'worst_violation': '',
#    'ending_time': 752.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 656.0,
#    'worst_violation': '',
#    'ending_time': 756.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 660.0,
#    'worst_violation': '',
#    'ending_time': 760.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 664.0,
#    'worst_violation': '',
#    'ending_time': 764.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 668.0,
#    'worst_violation': '',
#    'ending_time': 768.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 672.0,
#    'worst_violation': '',
#    'ending_time': 772.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 676.0,
#    'worst_violation': '',
#    'ending_time': 776.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 680.0,
#    'worst_violation': '',
#    'ending_time': 780.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 684.0,
#    'worst_violation': '',
#    'ending_time': 784.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 688.0,
#    'worst_violation': '',
#    'ending_time': 788.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 692.0,
#    'worst_violation': '',
#    'ending_time': 792.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 696.0,
#    'worst_violation': '',
#    'ending_time': 796.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 700.0,
#    'worst_violation': '',
#    'ending_time': 800.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 704.0,
#    'worst_violation': '',
#    'ending_time': 804.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 708.0,
#    'worst_violation': '',
#    'ending_time': 808.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 712.0,
#    'worst_violation': '',
#    'ending_time': 812.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 716.0,
#    'worst_violation': '',
#    'ending_time': 816.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 720.0,
#    'worst_violation': '',
#    'ending_time': 820.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 724.0,
#    'worst_violation': '',
#    'ending_time': 824.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 728.0,
#    'worst_violation': '',
#    'ending_time': 828.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 732.0,
#    'worst_violation': '',
#    'ending_time': 832.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 736.0,
#    'worst_violation': '',
#    'ending_time': 836.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 740.0,
#    'worst_violation': '',
#    'ending_time': 840.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 744.0,
#    'worst_violation': '',
#    'ending_time': 844.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 748.0,
#    'worst_violation': '',
#    'ending_time': 848.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 752.0,
#    'worst_violation': '',
#    'ending_time': 852.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 756.0,
#    'worst_violation': '',
#    'ending_time': 856.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 760.0,
#    'worst_violation': '',
#    'ending_time': 860.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 764.0,
#    'worst_violation': '',
#    'ending_time': 864.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 768.0,
#    'worst_violation': '',
#    'ending_time': 868.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 772.0,
#    'worst_violation': '',
#    'ending_time': 872.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 776.0,
#    'worst_violation': '',
#    'ending_time': 876.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 780.0,
#    'worst_violation': '',
#    'ending_time': 880.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 784.0,
#    'worst_violation': '',
#    'ending_time': 884.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 788.0,
#    'worst_violation': '',
#    'ending_time': 888.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 792.0,
#    'worst_violation': '',
#    'ending_time': 892.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 796.0,
#    'worst_violation': '',
#    'ending_time': 896.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 800.0,
#    'worst_violation': '',
#    'ending_time': 900.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 804.0,
#    'worst_violation': '',
#    'ending_time': 904.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 808.0,
#    'worst_violation': '',
#    'ending_time': 908.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 812.0,
#    'worst_violation': '',
#    'ending_time': 912.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 816.0,
#    'worst_violation': '',
#    'ending_time': 916.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 820.0,
#    'worst_violation': '',
#    'ending_time': 920.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 824.0,
#    'worst_violation': '',
#    'ending_time': 924.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 828.0,
#    'worst_violation': '',
#    'ending_time': 928.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 832.0,
#    'worst_violation': '',
#    'ending_time': 932.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 836.0,
#    'worst_violation': '',
#    'ending_time': 936.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 840.0,
#    'worst_violation': '',
#    'ending_time': 940.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 844.0,
#    'worst_violation': '',
#    'ending_time': 944.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 848.0,
#    'worst_violation': '',
#    'ending_time': 948.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 852.0,
#    'worst_violation': '',
#    'ending_time': 952.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 856.0,
#    'worst_violation': '',
#    'ending_time': 956.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 860.0,
#    'worst_violation': '',
#    'ending_time': 960.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 864.0,
#    'worst_violation': '',
#    'ending_time': 964.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 868.0,
#    'worst_violation': '',
#    'ending_time': 968.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 872.0,
#    'worst_violation': '',
#    'ending_time': 972.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 876.0,
#    'worst_violation': '',
#    'ending_time': 976.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 880.0,
#    'worst_violation': '',
#    'ending_time': 980.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 884.0,
#    'worst_violation': '',
#    'ending_time': 984.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 888.0,
#    'worst_violation': '',
#    'ending_time': 988.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 892.0,
#    'worst_violation': '',
#    'ending_time': 992.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 896.0,
#    'worst_violation': '',
#    'ending_time': 996.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 900.0,
#    'worst_violation': '',
#    'ending_time': 1000.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 904.0,
#    'worst_violation': '',
#    'ending_time': 1004.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 908.0,
#    'worst_violation': '',
#    'ending_time': 1008.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 912.0,
#    'worst_violation': '',
#    'ending_time': 1012.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 916.0,
#    'worst_violation': '',
#    'ending_time': 1016.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 920.0,
#    'worst_violation': '',
#    'ending_time': 1020.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 924.0,
#    'worst_violation': '',
#    'ending_time': 1024.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 928.0,
#    'worst_violation': '',
#    'ending_time': 1028.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 932.0,
#    'worst_violation': '',
#    'ending_time': 1032.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 936.0,
#    'worst_violation': '',
#    'ending_time': 1036.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 940.0,
#    'worst_violation': '',
#    'ending_time': 1040.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 944.0,
#    'worst_violation': '',
#    'ending_time': 1044.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 948.0,
#    'worst_violation': '',
#    'ending_time': 1048.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 952.0,
#    'worst_violation': '',
#    'ending_time': 1052.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 956.0,
#    'worst_violation': '',
#    'ending_time': 1056.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 960.0,
#    'worst_violation': '',
#    'ending_time': 1060.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 964.0,
#    'worst_violation': '',
#    'ending_time': 1064.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 968.0,
#    'worst_violation': '',
#    'ending_time': 1068.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 972.0,
#    'worst_violation': '',
#    'ending_time': 1072.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 976.0,
#    'worst_violation': '',
#    'ending_time': 1076.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 980.0,
#    'worst_violation': '',
#    'ending_time': 1080.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 984.0,
#    'worst_violation': '',
#    'ending_time': 1084.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 988.0,
#    'worst_violation': '',
#    'ending_time': 1088.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 992.0,
#    'worst_violation': '',
#    'ending_time': 1092.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 996.0,
#    'worst_violation': '',
#    'ending_time': 1096.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 1000.0,
#    'worst_violation': '',
#    'ending_time': 1100.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 1004.0,
#    'worst_violation': '',
#    'ending_time': 1104.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 1008.0,
#    'worst_violation': '',
#    'ending_time': 1108.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 1012.0,
#    'worst_violation': '',
#    'ending_time': 1112.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 1016.0,
#    'worst_violation': '',
#    'ending_time': 1116.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 1020.0,
#    'worst_violation': '',
#    'ending_time': 1120.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 1024.0,
#    'worst_violation': '',
#    'ending_time': 1124.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 1028.0,
#    'worst_violation': '',
#    'ending_time': 1128.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 1032.0,
#    'worst_violation': '',
#    'ending_time': 1132.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 1036.0,
#    'worst_violation': '',
#    'ending_time': 1136.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 1040.0,
#    'worst_violation': '',
#    'ending_time': 1140.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 1044.0,
#    'worst_violation': '',
#    'ending_time': 1144.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 1048.0,
#    'worst_violation': '',
#    'ending_time': 1148.0},
#   {'failure_mode': 'FM1: Full Blackout',
#    'starting_time': 1052.0,
#    'worst_violation': '',
#    'ending_time': 1152.0}]}
